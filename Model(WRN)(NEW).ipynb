# %%
import h5py
import os
import numpy as np

def unpickle(file):
    import cPickle
    with open(file, 'rb') as fo:
        dict = cPickle.load(fo)
    return dict

file = h5py.File('processed_data.h5','r+') 

#Retrieves all the preprocessed training and validation\testing data from a file

X_train = file['X_train'][...]
Y_train = file['Y_train'][...]
X_val = file['X_val'][...]
Y_val = file['Y_val'][...]
X_test = file['X_test'][...]
Y_test = file['Y_test'][...]

# Unpickles and retrieves class names and other meta informations of the database
classes = unpickle('cifar-10-batches-py/batches.meta') #keyword for label = label_names

print("Training sample shapes (input and output): "+str(X_train.shape)+" "+str(Y_train.shape))
print("Validation sample shapes (input and output): "+str(X_val.shape)+" "+str(Y_val.shape))
print("Testing sample shapes (input and output): "+str(X_test.shape)+" "+str(Y_test.shape))
# Out:
# Training sample shapes (input and output): (50000, 32, 32, 3) (50000, 10)
# Validation sample shapes (input and output): (10000, 32, 32, 3) (10000, 10)
# Testing sample shapes (input and output): (10000, 32, 32, 3) (10000, 10)

# %%
# Creates nested list. The outer list will list all the classess (0-9). And each of the classes represent the inner list which list all
#training data that belongs to that class. I used list because it is easy to keep on adding dynamically. Ndarrays may have needed 
#a predifined shape

classes_num = len(classes['label_names']) #classes_num = no. of classes

# Here, I am creating a special variable X_train_F which is basically a nested list.
# The outermost list of X_train_F will be a list of all the class values (0-9 where each value correspond to a class name)
# Each elements (class values) of the outermost list is actually also a list; a list of all the example data belonging
# to the particular class which corresponds to class value under which the data is listed. 

X_train_F = []

for i in xrange(0,classes_num):
    X_train_F.append([])


for i in xrange(0,len(X_train)):
    l = np.argmax(Y_train[i]) #l for label (in this case it's basically the index of class value elemenmts)  
    #(Y_train is one hot encoded. Argmax returns the index for maximum value which should be 1 and
    # that index should indicate the value)
    X_train_F[l].append(X_train[i])

# %%
import matplotlib.pyplot as plt
from scipy.misc import toimage
from scipy.misc import imresize
# %matplotlib inline

#function for showing pictures in grid along with labels

def picgrid(X_train,Y_train,gray=0):
    plt.figure(figsize=(7,7))
    ax=[]
    for i in xrange(0,25):
        img = toimage(X_train[i])
        ax.append(plt.subplot(5,5,i+1))
        ax[i].set_title( classes['label_names'][np.argmax(Y_train[i])],y=-0.3)
        ax[i].set_axis_off()
        if gray==0:
            plt.imshow(img)
        else:
            plt.imshow(img,cmap='gray')
    plt.subplots_adjust(hspace=0.3)
    plt.axis('off')
    plt.show()

# %%
import random


smoothing_factor = 0.1 #for label smoothing

def create_batches(batch_size,classes_num):
   
    s = int(batch_size/classes_num) #s denotes samples taken from each class to create the batch.
    no_of_batches = int(len(X_train)/batch_size)
    
    shuffled_indices_per_class =[]
    for i in xrange(0,classes_num):
        temp = np.arange(len(X_train_F[i]))
        np.random.shuffle(temp)
        shuffled_indices_per_class.append(temp)
        
    batches_X = []
    batches_Y = []
        
    for i in xrange(no_of_batches):
        
        shuffled_class_indices = np.arange(classes_num)
        np.random.shuffle(shuffled_class_indices)
        
        batch_Y = np.zeros((batch_size,classes_num),np.float32)
        batch_X = np.zeros((batch_size,32,32,3),np.float32)
        
        for index in xrange(0,classes_num):
            class_index = shuffled_class_indices[index]
            for j in xrange(0,s):
                batch_X[(index*s)+j] = X_train_F[class_index][shuffled_indices_per_class[class_index][i*s+j]] # Assign the s chosen random samples to the training batch
                batch_Y[(index*s)+j][class_index] = 1
                batch_Y[(index*s)+j] = (1-smoothing_factor)*batch_Y[(index*s)+j] + smoothing_factor/classes_num
        
        rs = batch_size - s*classes_num #rs denotes no. of random samples from random classes to take
                                        #in order to fill the batch if batch isn't divisble by classes_num
        #fill the rest of the batch with random data
        rand = random.sample(np.arange(len(X_train)),rs)
        j=0
        for k in xrange(s*classes_num,batch_size):
            batch_X[k] = X_train[int(rand[j])]
            batch_Y[k] = Y_train[int(rand[j])]
            batch_Y[k] = (1-smoothing_factor)*batch_Y[k] + smoothing_factor/classes_num
            j+=1

        batches_X.append(batch_X)
        batches_Y.append(batch_Y)
    
    return batches_X,batches_Y

batches_X,batches_Y = create_batches(64,classes_num) # A demo of the function at work

# Since each batch will have almost equal no. of cases from each class, no batch should be biased towards some particular classes

sample = random.randint(0,len(batches_X))
print "Sample arranged images in a batch: "
picgrid(batches_X[sample],batches_Y[sample])
# Out:
# Sample arranged images in a batch:

# %%
def random_crop(img):
    #result = np.zeros_like((img))
    c = np.random.randint(0,5)
    if c==0:
        crop = img[4:32,0:-4]
    elif c==1:
        crop = img[0:-4,0:-4]
    elif c==2:
        crop = img[2:-2,2:-2]
    elif c==3:
        crop = img[4:32,4:32]
    elif c==4:
        crop = img[0:-4,4:32]
    
    #translating cropped position
    #over the original image
    c = np.random.randint(0,5)
    if c==0:
        img[4:32,0:-4] = crop[:]
    elif c==1:
        img[0:-4,0:-4] = crop[:]
    elif c==2:
        img[2:-2,2:-2] = crop[:]
    elif c==3:
        img[4:32,4:32] = crop[:]
    elif c==4:
        img[0:-4,4:32] = crop[:]
        
    return img

def augment_batch(batch_X): #will be used to modify images realtime during training (real time data augmentation)
    
    aug_batch_X = np.zeros((len(batch_X),32,32,3))
   
    for i in xrange(0,len(batch_X)):
        
        hf = np.random.randint(0,2)
        
        if hf == 1: #hf denotes horizontal flip. 50-50 random chance to apply horizontal flip on images,
            batch_X[i] = np.fliplr(batch_X[i])
       
        # Remove the below cropping to apply random crops. But before that it's better to implement something like mirror padding
        # or any form of padding to increase the dimensions beforehand.
        
        c = np.random.randint(0,3)
        if c==1:
           #one in a three chance for cropping
           #randomly crop 28x28 portions and translate it.
            aug_batch_X[i] = random_crop(batch_X[i])
        else:
            aug_batch_X[i] = batch_X[i]
    
    return aug_batch_X
    
aug_batches_X=[]
for batch in batches_X:
    aug_batch_X = augment_batch(batch)
    aug_batches_X.append(aug_batch_X)

print "Sample batch training images after augmentation:"
picgrid(aug_batches_X[sample],batches_Y[sample])
# Out:
# Sample batch training images after augmentation:

# %%
def shuffle_batch(batch_X,batch_Y):
    shuffle = random.sample(np.arange(0,len(batch_X),1,'int'),len(batch_X))
    shuffled_batch_X = []
    shuffled_batch_Y = []
    
    for i in xrange(0,len(batch_X)):
        shuffled_batch_X.append(batch_X[int(shuffle[i])])
        shuffled_batch_Y.append(batch_Y[int(shuffle[i])])
    
    shuffled_batch_X = np.array(shuffled_batch_X)
    shuffled_batch_Y = np.array(shuffled_batch_Y)

    return shuffled_batch_X,shuffled_batch_Y

s_batches_X=[]
s_batches_Y=[]
for i in xrange(len(aug_batches_X)):
    s_batch_X,s_batch_Y = shuffle_batch(aug_batches_X[i],batches_Y[i])
    s_batches_X.append(s_batch_X)
    s_batches_Y.append(s_batch_Y)

print "Sample batch training images after shuffling"
picgrid(s_batches_X[sample],s_batches_Y[sample])
# Out:
# Sample batch training images after shuffling

# %%
def batch(batch_size): #one shortcut function to execute all necessary functions to create a training batch
    batches_X,batches_Y = create_batches(batch_size,classes_num)
    
    aug_batches_X=[]
    for batch in batches_X:
        aug_batch_X = augment_batch(batch)
        aug_batches_X.append(aug_batch_X)
        
    s_batches_X=[]
    s_batches_Y=[]
    
    for i in xrange(len(aug_batches_X)):
        s_batch_X,s_batch_Y = shuffle_batch(aug_batches_X[i],batches_Y[i])
        s_batches_X.append(s_batch_X)
        s_batches_Y.append(s_batch_Y)
    
    return s_batches_X,s_batches_Y

# %%
import tensorflow as tf

#Hyper Parameters!

learning_rate = 0.01
init_lr = learning_rate
batch_size = 64
epochs = 500
layers = 16
beta = 0.0001 #l2 regularization scale
#ensemble = 1 #no. of models to be ensembled (minimum: 1)

K = 8 #(deepening factor)

n_classes = classes_num # another useless step that I made due to certain reasons. 

# tf Graph input

x = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.float32, [None,classes_num])
phase = tf.placeholder(tf.bool)
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x,shape,strides,scope):
    # Conv2D wrapper
    with tf.variable_scope(scope+"regularize",reuse=False):
        W = tf.Variable(tf.truncated_normal(shape=shape,stddev=5e-2))
    b = tf.Variable(tf.truncated_normal(shape=[shape[3]],stddev=5e-2))
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return x

def activate(x,phase):
    #wrapper for performing batch normalization and elu activation
    x = tf.contrib.layers.batch_norm(x, center=True, scale=True,variables_collections=["batch_norm_non_trainable_variables_collection"],updates_collections=None, decay=0.9,is_training=phase,zero_debias_moving_mean=True, fused=True)
    return tf.nn.elu(x)


def wideres33block(X,N,K,iw,bw,s,dropout,phase,scope):
    
    # Creates N no. of 3,3 type residual blocks with dropout that consitute the conv2/3/4 blocks
    # with widening factor K and X as input. s is stride and bw is base width (no. of filters before multiplying with k)
    # iw is input width.
    # (see https://arxiv.org/abs/1605.07146 paper for details on the block)
    # In this case, dropout = probability to keep the neuron enabled.
    # phase = true when training, false otherwise.
    
    conv33_1 = conv2d(X,[3,3,iw,bw*K],s,scope)
    conv33_1 = activate(conv33_1,phase)
    conv33_1 = tf.nn.dropout(conv33_1,dropout)
    
    conv33_2 = conv2d(conv33_1,[3,3,bw*K,bw*K],1,scope)
    conv_skip= conv2d(X,[1,1,iw,bw*K],s,scope) #shortcut connection

    
    caddtable = tf.add(conv33_2,conv_skip)
    
    #1st of the N blocks for conv2/3/4 block ends here. The rest of N-1 blocks will be implemented next with a loop.

    for i in range(0,N-1):
        
        C = caddtable
        Cactivated = activate(C,phase)
        
        conv33_1 = conv2d(Cactivated,[3,3,bw*K,bw*K],1,scope)
        conv33_1 = activate(conv33_1,phase)
        
        conv33_1 = tf.nn.dropout(conv33_1,dropout)
            
        conv33_2 = conv2d(conv33_1,[3,3,bw*K,bw*K],1,scope)
        caddtable = tf.add(conv33_2,C)
    
    return activate(caddtable,phase)


    
def WRN(x,dropout,phase,layers,K,scope): #Wide residual network

    # 1 conv + 3 convblocks*(3 conv layers *1 group for each block + 2 conv layers*(N-1) groups for each block [total 1+N-1 = N groups]) = layers
    # 3*2*(N-1) = layers - 1 - 3*3
    # N = (layers -10)/6 + 1
    # So N = (layers-4)/6

    N = (layers-4)/6
    
    conv1 = conv2d(x,[3,3,3,16],1,scope)
    conv1 = activate(conv1,phase)

    conv2 = wideres33block(conv1,N,K,16,16,1,dropout,phase,scope)
    conv3 = wideres33block(conv2,N,K,16*K,32,2,dropout,phase,scope)
    conv4 = wideres33block(conv3,N,K,32*K,64,2,dropout,phase,scope)

    pooled = tf.nn.avg_pool(conv4,ksize=[1,8,8,1],strides=[1,1,1,1],padding='VALID')
    
    #Initialize weights and biases for fully connected layers
    with tf.variable_scope(scope+"regularize",reuse=False):
        wd1 = tf.Variable(tf.truncated_normal([1*1*64*K,64*K],stddev=5e-2))
        wout = tf.Variable(tf.truncated_normal([64*K, n_classes]))
    bd1 = tf.Variable(tf.constant(0.1,shape=[64*K]))
    bout = tf.Variable(tf.constant(0.1,shape=[n_classes]))

    # Fully connected layer
    # Reshape pooling layer output to fit fully connected layer input
    fc1 = tf.reshape(pooled, [-1, wd1.get_shape().as_list()[0]])   
    fc1 = tf.add(tf.matmul(fc1, wd1), bd1)
    fc1 = tf.nn.elu(fc1)
    # Output, class prediction
    out = tf.add(tf.matmul(fc1, wout), bout)
    
    return out

# %%
# Construct model

model = WRN(x,keep_prob,phase,layers=layers,K=K,scope='1')

#l2 regularization
weights = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='1regularize')

regularizer=0
for i in xrange(len(weights)):
    regularizer += tf.nn.l2_loss(weights[i])
    

#cross entropy loss
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=model,labels=y) + beta*regularizer)


global_step = tf.Variable(0, trainable=False)

#optimizer 
optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, 
                                       momentum = 0.9, 
                                       use_nesterov=True).minimize(cost,global_step=global_step)

# Evaluate model
correct_pred = tf.equal(tf.argmax(model,1),tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
prediction = tf.nn.softmax(logits=model)

# Initializing the variables
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess: # Start Tensorflow Session
    
    saver = tf.train.Saver() # Prepares variable for saving the model
    sess.run(init) #initialize all variables
    step = 1   
    loss_list=[]
    acc_list=[]
    val_loss_list=[]
    val_acc_list=[]
    best_val_acc=0
    total_loss=0
    total_acc=0
    avg_loss=0
    avg_acc=0
    val_batch_size = batch_size
    
    
    threshold = 0.5 #if training accuracy is 100-threshold or less, training will stop 
    
    while step <= epochs:
        
        
        # A little bit of Learning rate scheduling
        if step == 60:
            learning_rate = 0.01
        elif step == 120:
            learning_rate = 0.004
        elif step == 160:
            learning_rate = 0.0008

        
        batches_X, batches_Y = batch(batch_size)
        
        for i in xrange(len(batches_X)):
            # Run optimization operation (backpropagation)
            _,loss,acc = sess.run([optimizer,cost,accuracy],
                                   feed_dict={x: batches_X[i], y: batches_Y[i], 
                                   keep_prob: 0.7,
                                   phase: True})
            total_loss += loss
            total_acc += acc
            
            if i%100 == 0:
                print "Iter " + str((step-1)*len(batches_X)+i+1) + ", Minibatch Loss= " + \
                  "{:.3f}".format(loss) + ", Minibatch Accuracy= " + \
                  "{:.3f}%".format(acc*100)

     
                      
        total_val_loss=0
        total_val_acc=0
        val_loss=0
        val_acc=0
        avg_val_loss=0
        avg_val_acc=0
            
        i=0
        count=0
        while i<len(X_val):

            if i+val_batch_size<len(X_val):
                val_loss, val_acc = sess.run([cost, accuracy], 
                                            feed_dict={x: X_val[i:i+val_batch_size],
                                                       y: Y_val[i:i+val_batch_size],
                                                       keep_prob: 1,
                                                       phase: False})
            else:
                val_loss, val_acc = sess.run([cost, accuracy], 
                                            feed_dict={x: X_val[i:],
                                                       y: Y_val[i:],
                                                       keep_prob: 1,
                                                       phase: False})
                              
            total_val_loss = total_val_loss + val_loss
            total_val_acc = total_val_acc + val_acc
            count+=1
                
            i+=val_batch_size
  

 
        avg_val_loss = total_val_loss/count # Average validation loss
        avg_val_acc = total_val_acc/count # Average validation accuracy
            
             
        val_loss_list.append(avg_val_loss) # Storing values in list for plotting later on.
        val_acc_list.append(avg_val_acc) # Storing values in list for plotting later on.
            
        avg_loss = total_loss/len(batches_X) # Average mini-batch training loss
        avg_acc = total_acc/len(batches_X)   # Average mini-batch training accuracy
        loss_list.append(avg_loss) # Storing values in list for plotting later on.
        acc_list.append(avg_acc) # Storing values in list for plotting later on.
            
        total_loss=0
        total_acc=0

        print "\nEpoch " + str(step) + ", Validation Loss= " + \
                "{:.3f}".format(avg_val_loss) + ", validation Accuracy= " + \
                "{:.3f}%".format(avg_val_acc*100)+""
        print "Epoch " + str(step) + ", Average Training Loss= " + \
                "{:.3f}".format(avg_loss) + ", Average Training Accuracy= " + \
                "{:.3f}%".format(avg_acc*100)+""
                    
        if avg_val_acc >= best_val_acc: # When better accuracy is received than previous best validation accuracy
                
            best_val_acc = avg_val_acc # update value of best validation accuracy received yet.
            saver.save(sess, 'Model_Backup/model.ckpt') # save_model including model variables (weights, biases etc.)
            print "Checkpoint created!"
                
                
        print ""
            
        if (100-(avg_acc*100)) <= threshold:
            print "\nConvergence Threshold Reached!"
            break
              
        step += 1
        
    print "\nOptimization Finished!\n"
    
    print "Best Validation Accuracy: %.3f%%"%((best_val_acc)*100)
    
    print 'Loading pre-trained weights for the model...'
    saver = tf.train.Saver()
    saver.restore(sess, 'Model_Backup/model.ckpt')
    sess.run(tf.global_variables())
    print '\nRESTORATION COMPLETE\n'
    
    print 'Testing Model Performance...'
    test_batch_size = batch_size
    total_test_loss=0
    total_test_acc=0
    test_loss=0
    test_acc=0
    avg_test_loss=0
    avg_test_acc=0
            
    i=0
    count=0
    while i<len(X_test):
        
        if (i+test_batch_size)<len(X_test):
            test_loss, test_acc = sess.run([cost, accuracy], 
                                         feed_dict={x: X_test[i:i+test_batch_size],
                                                    y: Y_test[i:i+test_batch_size],
                                                    keep_prob: 1,
                                                    phase: False})
        else:
            test_loss, test_acc = sess.run([cost, accuracy], 
                                            feed_dict={x: X_test[i:],
                                                       y: Y_test[i:],
                                                       keep_prob: 1,
                                                       phase: False})
   
        total_test_loss = total_test_loss+test_loss
        total_test_acc = total_test_acc+test_acc
        count+=1
        
        i+=test_batch_size
             
    avg_test_loss = total_test_loss/count # Average test loss
    avg_test_acc = total_test_acc/count # Average test accuracy
    
    print "Test Loss = " + \
          "{:.3f}".format(avg_test_loss) + ", Test Accuracy = " + \
          "{:.3f}%".format(avg_test_acc*100)
# Out:
# Iter 1, Minibatch Loss= 7.933, Minibatch Accuracy= 7.812%
# Iter 101, Minibatch Loss= 3.545, Minibatch Accuracy= 23.438%
# Iter 201, Minibatch Loss= 3.227, Minibatch Accuracy= 37.500%
# Iter 301, Minibatch Loss= 3.356, Minibatch Accuracy= 28.125%
# Iter 401, Minibatch Loss= 3.231, Minibatch Accuracy= 28.125%
# Iter 501, Minibatch Loss= 3.242, Minibatch Accuracy= 29.688%
# Iter 601, Minibatch Loss= 3.349, Minibatch Accuracy= 28.125%
# Iter 701, Minibatch Loss= 3.105, Minibatch Accuracy= 37.500%
#
# Epoch 1, Validation Loss= 2.971, validation Accuracy= 38.754%
# Epoch 1, Average Training Loss= 4.991, Average Training Accuracy= 30.964%
# Checkpoint created!
#
# Iter 782, Minibatch Loss= 3.192, Minibatch Accuracy= 40.625%
# Iter 882, Minibatch Loss= 3.204, Minibatch Accuracy= 40.625%
# Iter 982, Minibatch Loss= 3.121, Minibatch Accuracy= 39.062%
# Iter 1082, Minibatch Loss= 3.060, Minibatch Accuracy= 53.125%
# Iter 1182, Minibatch Loss= 3.025, Minibatch Accuracy= 35.938%
# Iter 1282, Minibatch Loss= 3.043, Minibatch Accuracy= 37.500%
# Iter 1382, Minibatch Loss= 2.983, Minibatch Accuracy= 50.000%
# Iter 1482, Minibatch Loss= 3.154, Minibatch Accuracy= 31.250%
#
# Epoch 2, Validation Loss= 2.803, validation Accuracy= 44.974%
# Epoch 2, Average Training Loss= 3.063, Average Training Accuracy= 40.525%
# Checkpoint created!
#
# Iter 1563, Minibatch Loss= 3.120, Minibatch Accuracy= 37.500%
# Iter 1663, Minibatch Loss= 2.739, Minibatch Accuracy= 54.688%
# Iter 1763, Minibatch Loss= 3.000, Minibatch Accuracy= 40.625%
# Iter 1863, Minibatch Loss= 2.726, Minibatch Accuracy= 59.375%
# Iter 1963, Minibatch Loss= 2.886, Minibatch Accuracy= 51.562%
# Iter 2063, Minibatch Loss= 2.966, Minibatch Accuracy= 45.312%
# Iter 2163, Minibatch Loss= 2.944, Minibatch Accuracy= 45.312%
# Iter 2263, Minibatch Loss= 2.940, Minibatch Accuracy= 43.750%
#
# Epoch 3, Validation Loss= 2.684, validation Accuracy= 48.348%
# Epoch 3, Average Training Loss= 2.951, Average Training Accuracy= 45.391%
# Checkpoint created!
#
# Iter 2344, Minibatch Loss= 2.894, Minibatch Accuracy= 46.875%
# Iter 2444, Minibatch Loss= 3.065, Minibatch Accuracy= 35.938%
# Iter 2544, Minibatch Loss= 2.830, Minibatch Accuracy= 50.000%
# Iter 2644, Minibatch Loss= 3.023, Minibatch Accuracy= 39.062%
# Iter 2744, Minibatch Loss= 2.890, Minibatch Accuracy= 53.125%
# Iter 2844, Minibatch Loss= 2.899, Minibatch Accuracy= 46.875%
# Iter 2944, Minibatch Loss= 3.006, Minibatch Accuracy= 39.062%
# Iter 3044, Minibatch Loss= 2.791, Minibatch Accuracy= 56.250%
#
# Epoch 4, Validation Loss= 2.589, validation Accuracy= 50.965%
# Epoch 4, Average Training Loss= 2.852, Average Training Accuracy= 49.314%
# Checkpoint created!
#
# Iter 3125, Minibatch Loss= 2.796, Minibatch Accuracy= 45.312%
# Iter 3225, Minibatch Loss= 2.766, Minibatch Accuracy= 51.562%
# Iter 3325, Minibatch Loss= 2.835, Minibatch Accuracy= 51.562%
# Iter 3425, Minibatch Loss= 2.695, Minibatch Accuracy= 56.250%
# Iter 3525, Minibatch Loss= 2.736, Minibatch Accuracy= 54.688%
# Iter 3625, Minibatch Loss= 2.776, Minibatch Accuracy= 46.875%
# Iter 3725, Minibatch Loss= 2.700, Minibatch Accuracy= 56.250%
# Iter 3825, Minibatch Loss= 2.707, Minibatch Accuracy= 51.562%
#
# Epoch 5, Validation Loss= 2.469, validation Accuracy= 56.310%
# Epoch 5, Average Training Loss= 2.765, Average Training Accuracy= 52.703%
# Checkpoint created!
#
# Iter 3906, Minibatch Loss= 2.573, Minibatch Accuracy= 64.062%
# Iter 4006, Minibatch Loss= 2.566, Minibatch Accuracy= 62.500%
# Iter 4106, Minibatch Loss= 2.558, Minibatch Accuracy= 62.500%
# Iter 4206, Minibatch Loss= 2.649, Minibatch Accuracy= 54.688%
# Iter 4306, Minibatch Loss= 2.727, Minibatch Accuracy= 56.250%
# Iter 4406, Minibatch Loss= 2.617, Minibatch Accuracy= 57.812%
# Iter 4506, Minibatch Loss= 2.575, Minibatch Accuracy= 56.250%
# Iter 4606, Minibatch Loss= 2.629, Minibatch Accuracy= 51.562%
#
# Epoch 6, Validation Loss= 2.379, validation Accuracy= 58.459%
# Epoch 6, Average Training Loss= 2.677, Average Training Accuracy= 56.138%
# Checkpoint created!
#
# Iter 4687, Minibatch Loss= 2.741, Minibatch Accuracy= 53.125%
# Iter 4787, Minibatch Loss= 2.571, Minibatch Accuracy= 64.062%
# Iter 4887, Minibatch Loss= 2.574, Minibatch Accuracy= 56.250%
# Iter 4987, Minibatch Loss= 2.776, Minibatch Accuracy= 50.000%
# Iter 5087, Minibatch Loss= 2.530, Minibatch Accuracy= 62.500%
# Iter 5187, Minibatch Loss= 2.580, Minibatch Accuracy= 56.250%
# Iter 5287, Minibatch Loss= 2.672, Minibatch Accuracy= 54.688%
# Iter 5387, Minibatch Loss= 2.598, Minibatch Accuracy= 57.812%
#
# Epoch 7, Validation Loss= 2.281, validation Accuracy= 61.644%
# Epoch 7, Average Training Loss= 2.605, Average Training Accuracy= 58.863%
# Checkpoint created!
#
# Iter 5468, Minibatch Loss= 2.632, Minibatch Accuracy= 53.125%
# Iter 5568, Minibatch Loss= 2.571, Minibatch Accuracy= 57.812%
# Iter 5668, Minibatch Loss= 2.523, Minibatch Accuracy= 62.500%
# Iter 5768, Minibatch Loss= 2.574, Minibatch Accuracy= 56.250%
# Iter 5868, Minibatch Loss= 2.374, Minibatch Accuracy= 73.438%
# Iter 5968, Minibatch Loss= 2.695, Minibatch Accuracy= 53.125%
# Iter 6068, Minibatch Loss= 2.641, Minibatch Accuracy= 53.125%
# Iter 6168, Minibatch Loss= 2.597, Minibatch Accuracy= 59.375%
#
# Epoch 8, Validation Loss= 2.185, validation Accuracy= 64.729%
# Epoch 8, Average Training Loss= 2.537, Average Training Accuracy= 61.694%
# Checkpoint created!
#
# Iter 6249, Minibatch Loss= 2.484, Minibatch Accuracy= 57.812%
# Iter 6349, Minibatch Loss= 2.489, Minibatch Accuracy= 62.500%
# Iter 6449, Minibatch Loss= 2.554, Minibatch Accuracy= 57.812%
# Iter 6549, Minibatch Loss= 2.452, Minibatch Accuracy= 64.062%
# Iter 6649, Minibatch Loss= 2.469, Minibatch Accuracy= 67.188%
# Iter 6749, Minibatch Loss= 2.346, Minibatch Accuracy= 70.312%
# Iter 6849, Minibatch Loss= 2.459, Minibatch Accuracy= 64.062%
# Iter 6949, Minibatch Loss= 2.472, Minibatch Accuracy= 65.625%
#
# Epoch 9, Validation Loss= 2.151, validation Accuracy= 64.640%
# Epoch 9, Average Training Loss= 2.469, Average Training Accuracy= 64.291%
#
# Iter 7030, Minibatch Loss= 2.474, Minibatch Accuracy= 60.938%
# Iter 7130, Minibatch Loss= 2.435, Minibatch Accuracy= 62.500%
# Iter 7230, Minibatch Loss= 2.499, Minibatch Accuracy= 65.625%
# Iter 7330, Minibatch Loss= 2.343, Minibatch Accuracy= 65.625%
# Iter 7430, Minibatch Loss= 2.415, Minibatch Accuracy= 65.625%
# Iter 7530, Minibatch Loss= 2.409, Minibatch Accuracy= 60.938%
# Iter 7630, Minibatch Loss= 2.532, Minibatch Accuracy= 62.500%
# Iter 7730, Minibatch Loss= 2.613, Minibatch Accuracy= 57.812%
#
# Epoch 10, Validation Loss= 2.110, validation Accuracy= 65.715%
# Epoch 10, Average Training Loss= 2.418, Average Training Accuracy= 65.777%
# Checkpoint created!
#
# Iter 7811, Minibatch Loss= 2.208, Minibatch Accuracy= 71.875%
# Iter 7911, Minibatch Loss= 2.408, Minibatch Accuracy= 68.750%
# Iter 8011, Minibatch Loss= 2.387, Minibatch Accuracy= 67.188%
# Iter 8111, Minibatch Loss= 2.264, Minibatch Accuracy= 75.000%
# Iter 8211, Minibatch Loss= 2.348, Minibatch Accuracy= 67.188%
# Iter 8311, Minibatch Loss= 2.476, Minibatch Accuracy= 59.375%
# Iter 8411, Minibatch Loss= 2.141, Minibatch Accuracy= 78.125%
# Iter 8511, Minibatch Loss= 2.195, Minibatch Accuracy= 78.125%
#
# Epoch 11, Validation Loss= 2.024, validation Accuracy= 69.148%
# Epoch 11, Average Training Loss= 2.366, Average Training Accuracy= 67.632%
# Checkpoint created!
#
# Iter 8592, Minibatch Loss= 2.439, Minibatch Accuracy= 68.750%
# Iter 8692, Minibatch Loss= 2.329, Minibatch Accuracy= 70.312%
# Iter 8792, Minibatch Loss= 2.261, Minibatch Accuracy= 70.312%
# Iter 8892, Minibatch Loss= 2.135, Minibatch Accuracy= 71.875%
# Iter 8992, Minibatch Loss= 2.219, Minibatch Accuracy= 73.438%
# Iter 9092, Minibatch Loss= 2.369, Minibatch Accuracy= 67.188%
# Iter 9192, Minibatch Loss= 2.346, Minibatch Accuracy= 67.188%
# Iter 9292, Minibatch Loss= 2.275, Minibatch Accuracy= 65.625%
#
# Epoch 12, Validation Loss= 1.954, validation Accuracy= 70.541%
# Epoch 12, Average Training Loss= 2.321, Average Training Accuracy= 69.004%
# Checkpoint created!
#
# Iter 9373, Minibatch Loss= 2.133, Minibatch Accuracy= 78.125%
# Iter 9473, Minibatch Loss= 2.344, Minibatch Accuracy= 71.875%
# Iter 9573, Minibatch Loss= 2.169, Minibatch Accuracy= 79.688%
# Iter 9673, Minibatch Loss= 2.235, Minibatch Accuracy= 76.562%
# Iter 9773, Minibatch Loss= 2.348, Minibatch Accuracy= 67.188%
# Iter 9873, Minibatch Loss= 2.306, Minibatch Accuracy= 65.625%
# Iter 9973, Minibatch Loss= 2.229, Minibatch Accuracy= 68.750%
# Iter 10073, Minibatch Loss= 2.309, Minibatch Accuracy= 67.188%
#
# Epoch 13, Validation Loss= 1.904, validation Accuracy= 71.825%
# Epoch 13, Average Training Loss= 2.280, Average Training Accuracy= 70.280%
# Checkpoint created!
#
# Iter 10154, Minibatch Loss= 2.229, Minibatch Accuracy= 73.438%
# Iter 10254, Minibatch Loss= 2.107, Minibatch Accuracy= 76.562%
# Iter 10354, Minibatch Loss= 2.218, Minibatch Accuracy= 67.188%
# Iter 10454, Minibatch Loss= 2.162, Minibatch Accuracy= 71.875%
# Iter 10554, Minibatch Loss= 2.247, Minibatch Accuracy= 75.000%
# Iter 10654, Minibatch Loss= 2.249, Minibatch Accuracy= 67.188%
# Iter 10754, Minibatch Loss= 2.261, Minibatch Accuracy= 71.875%
# Iter 10854, Minibatch Loss= 2.208, Minibatch Accuracy= 71.875%
#
# Epoch 14, Validation Loss= 1.895, validation Accuracy= 71.935%
# Epoch 14, Average Training Loss= 2.235, Average Training Accuracy= 71.737%
# Checkpoint created!
#
# Iter 10935, Minibatch Loss= 2.456, Minibatch Accuracy= 59.375%
# Iter 11035, Minibatch Loss= 2.209, Minibatch Accuracy= 70.312%
# Iter 11135, Minibatch Loss= 2.119, Minibatch Accuracy= 76.562%
# Iter 11235, Minibatch Loss= 2.195, Minibatch Accuracy= 75.000%
# Iter 11335, Minibatch Loss= 2.242, Minibatch Accuracy= 71.875%
# Iter 11435, Minibatch Loss= 2.232, Minibatch Accuracy= 71.875%
# Iter 11535, Minibatch Loss= 2.158, Minibatch Accuracy= 75.000%
# Iter 11635, Minibatch Loss= 2.303, Minibatch Accuracy= 67.188%
#
# Epoch 15, Validation Loss= 1.806, validation Accuracy= 74.632%
# Epoch 15, Average Training Loss= 2.195, Average Training Accuracy= 72.679%
# Checkpoint created!
#
# Iter 11716, Minibatch Loss= 2.177, Minibatch Accuracy= 71.875%
# Iter 11816, Minibatch Loss= 2.045, Minibatch Accuracy= 81.250%
# Iter 11916, Minibatch Loss= 2.013, Minibatch Accuracy= 79.688%
# Iter 12016, Minibatch Loss= 2.158, Minibatch Accuracy= 68.750%
# Iter 12116, Minibatch Loss= 2.280, Minibatch Accuracy= 70.312%
# Iter 12216, Minibatch Loss= 2.112, Minibatch Accuracy= 73.438%
# Iter 12316, Minibatch Loss= 2.188, Minibatch Accuracy= 78.125%
# Iter 12416, Minibatch Loss= 2.107, Minibatch Accuracy= 78.125%
#
# Epoch 16, Validation Loss= 1.786, validation Accuracy= 74.721%
# Epoch 16, Average Training Loss= 2.154, Average Training Accuracy= 73.912%
# Checkpoint created!
#
# Iter 12497, Minibatch Loss= 2.147, Minibatch Accuracy= 71.875%
# Iter 12597, Minibatch Loss= 2.103, Minibatch Accuracy= 71.875%
# Iter 12697, Minibatch Loss= 2.194, Minibatch Accuracy= 68.750%
# Iter 12797, Minibatch Loss= 1.921, Minibatch Accuracy= 90.625%
# Iter 12897, Minibatch Loss= 2.081, Minibatch Accuracy= 76.562%
# Iter 12997, Minibatch Loss= 2.022, Minibatch Accuracy= 79.688%
# Iter 13097, Minibatch Loss= 2.050, Minibatch Accuracy= 73.438%
# Iter 13197, Minibatch Loss= 2.214, Minibatch Accuracy= 73.438%
#
# Epoch 17, Validation Loss= 1.727, validation Accuracy= 75.926%
# Epoch 17, Average Training Loss= 2.117, Average Training Accuracy= 75.076%
# Checkpoint created!
#
# Iter 13278, Minibatch Loss= 2.079, Minibatch Accuracy= 76.562%
# Iter 13378, Minibatch Loss= 2.087, Minibatch Accuracy= 81.250%
# Iter 13478, Minibatch Loss= 2.205, Minibatch Accuracy= 68.750%
# Iter 13578, Minibatch Loss= 2.128, Minibatch Accuracy= 71.875%
# Iter 13678, Minibatch Loss= 2.158, Minibatch Accuracy= 73.438%
# Iter 13778, Minibatch Loss= 2.177, Minibatch Accuracy= 65.625%
# Iter 13878, Minibatch Loss= 2.021, Minibatch Accuracy= 76.562%
# Iter 13978, Minibatch Loss= 2.189, Minibatch Accuracy= 73.438%
#
# Epoch 18, Validation Loss= 1.696, validation Accuracy= 76.433%
# Epoch 18, Average Training Loss= 2.082, Average Training Accuracy= 76.076%
# Checkpoint created!
#
# Iter 14059, Minibatch Loss= 1.997, Minibatch Accuracy= 82.812%
# Iter 14159, Minibatch Loss= 2.018, Minibatch Accuracy= 78.125%
# Iter 14259, Minibatch Loss= 2.014, Minibatch Accuracy= 78.125%
# Iter 14359, Minibatch Loss= 2.065, Minibatch Accuracy= 78.125%
# Iter 14459, Minibatch Loss= 2.087, Minibatch Accuracy= 78.125%
# Iter 14559, Minibatch Loss= 2.128, Minibatch Accuracy= 68.750%
# Iter 14659, Minibatch Loss= 2.112, Minibatch Accuracy= 73.438%
# Iter 14759, Minibatch Loss= 2.093, Minibatch Accuracy= 73.438%
#
# Epoch 19, Validation Loss= 1.668, validation Accuracy= 77.339%
# Epoch 19, Average Training Loss= 2.045, Average Training Accuracy= 77.173%
# Checkpoint created!
#
# Iter 14840, Minibatch Loss= 2.091, Minibatch Accuracy= 75.000%
# Iter 14940, Minibatch Loss= 2.035, Minibatch Accuracy= 78.125%
# Iter 15040, Minibatch Loss= 1.951, Minibatch Accuracy= 78.125%
# Iter 15140, Minibatch Loss= 1.986, Minibatch Accuracy= 75.000%
# Iter 15240, Minibatch Loss= 2.117, Minibatch Accuracy= 73.438%
# Iter 15340, Minibatch Loss= 1.991, Minibatch Accuracy= 73.438%
# Iter 15440, Minibatch Loss= 2.053, Minibatch Accuracy= 76.562%
# Iter 15540, Minibatch Loss= 2.148, Minibatch Accuracy= 75.000%
#
# Epoch 20, Validation Loss= 1.628, validation Accuracy= 78.205%
# Epoch 20, Average Training Loss= 2.010, Average Training Accuracy= 78.161%
# Checkpoint created!
#
# Iter 15621, Minibatch Loss= 2.059, Minibatch Accuracy= 78.125%
# Iter 15721, Minibatch Loss= 2.021, Minibatch Accuracy= 75.000%
# Iter 15821, Minibatch Loss= 2.109, Minibatch Accuracy= 68.750%
# Iter 15921, Minibatch Loss= 1.893, Minibatch Accuracy= 81.250%
# Iter 16021, Minibatch Loss= 1.852, Minibatch Accuracy= 87.500%
# Iter 16121, Minibatch Loss= 2.040, Minibatch Accuracy= 82.812%
# Iter 16221, Minibatch Loss= 1.923, Minibatch Accuracy= 78.125%
# Iter 16321, Minibatch Loss= 2.020, Minibatch Accuracy= 75.000%
#
# Epoch 21, Validation Loss= 1.587, validation Accuracy= 79.479%
# Epoch 21, Average Training Loss= 1.984, Average Training Accuracy= 78.713%
# Checkpoint created!
#
# Iter 16402, Minibatch Loss= 1.834, Minibatch Accuracy= 89.062%
# Iter 16502, Minibatch Loss= 2.121, Minibatch Accuracy= 75.000%
# Iter 16602, Minibatch Loss= 2.010, Minibatch Accuracy= 79.688%
# Iter 16702, Minibatch Loss= 1.842, Minibatch Accuracy= 85.938%
# Iter 16802, Minibatch Loss= 1.873, Minibatch Accuracy= 78.125%
# Iter 16902, Minibatch Loss= 1.946, Minibatch Accuracy= 82.812%
# Iter 17002, Minibatch Loss= 2.044, Minibatch Accuracy= 76.562%
# Iter 17102, Minibatch Loss= 1.969, Minibatch Accuracy= 81.250%
#
# Epoch 22, Validation Loss= 1.580, validation Accuracy= 78.822%
# Epoch 22, Average Training Loss= 1.952, Average Training Accuracy= 79.669%
#
# Iter 17183, Minibatch Loss= 1.929, Minibatch Accuracy= 81.250%
# Iter 17283, Minibatch Loss= 1.975, Minibatch Accuracy= 78.125%
# Iter 17383, Minibatch Loss= 2.063, Minibatch Accuracy= 75.000%
# Iter 17483, Minibatch Loss= 2.069, Minibatch Accuracy= 70.312%
# Iter 17583, Minibatch Loss= 1.983, Minibatch Accuracy= 82.812%
# Iter 17683, Minibatch Loss= 1.888, Minibatch Accuracy= 85.938%
# Iter 17783, Minibatch Loss= 2.001, Minibatch Accuracy= 78.125%
# Iter 17883, Minibatch Loss= 1.925, Minibatch Accuracy= 79.688%
#
# Epoch 23, Validation Loss= 1.528, validation Accuracy= 80.732%
# Epoch 23, Average Training Loss= 1.924, Average Training Accuracy= 80.394%
# Checkpoint created!
#
# Iter 17964, Minibatch Loss= 1.811, Minibatch Accuracy= 84.375%
# Iter 18064, Minibatch Loss= 2.010, Minibatch Accuracy= 76.562%
# Iter 18164, Minibatch Loss= 1.774, Minibatch Accuracy= 92.188%
# Iter 18264, Minibatch Loss= 1.815, Minibatch Accuracy= 82.812%
# Iter 18364, Minibatch Loss= 1.953, Minibatch Accuracy= 76.562%
# Iter 18464, Minibatch Loss= 1.878, Minibatch Accuracy= 79.688%
# Iter 18564, Minibatch Loss= 1.779, Minibatch Accuracy= 82.812%
# Iter 18664, Minibatch Loss= 1.759, Minibatch Accuracy= 89.062%
#
# Epoch 24, Validation Loss= 1.514, validation Accuracy= 80.902%
# Epoch 24, Average Training Loss= 1.896, Average Training Accuracy= 80.998%
# Checkpoint created!
#
# Iter 18745, Minibatch Loss= 1.914, Minibatch Accuracy= 79.688%
# Iter 18845, Minibatch Loss= 1.879, Minibatch Accuracy= 79.688%
# Iter 18945, Minibatch Loss= 1.824, Minibatch Accuracy= 87.500%
# Iter 19045, Minibatch Loss= 1.780, Minibatch Accuracy= 84.375%
# Iter 19145, Minibatch Loss= 1.908, Minibatch Accuracy= 81.250%
# Iter 19245, Minibatch Loss= 1.828, Minibatch Accuracy= 82.812%
# Iter 19345, Minibatch Loss= 1.740, Minibatch Accuracy= 89.062%
# Iter 19445, Minibatch Loss= 1.747, Minibatch Accuracy= 85.938%
#
# Epoch 25, Validation Loss= 1.468, validation Accuracy= 81.857%
# Epoch 25, Average Training Loss= 1.872, Average Training Accuracy= 81.572%
# Checkpoint created!
#
# Iter 19526, Minibatch Loss= 1.730, Minibatch Accuracy= 85.938%
# Iter 19626, Minibatch Loss= 1.884, Minibatch Accuracy= 84.375%
# Iter 19726, Minibatch Loss= 1.782, Minibatch Accuracy= 85.938%
# Iter 19826, Minibatch Loss= 1.811, Minibatch Accuracy= 81.250%
# Iter 19926, Minibatch Loss= 1.783, Minibatch Accuracy= 82.812%
# Iter 20026, Minibatch Loss= 1.821, Minibatch Accuracy= 85.938%
# Iter 20126, Minibatch Loss= 1.819, Minibatch Accuracy= 82.812%
# Iter 20226, Minibatch Loss= 1.722, Minibatch Accuracy= 87.500%
#
# Epoch 26, Validation Loss= 1.448, validation Accuracy= 82.514%
# Epoch 26, Average Training Loss= 1.845, Average Training Accuracy= 82.202%
# Checkpoint created!
#
# Iter 20307, Minibatch Loss= 1.638, Minibatch Accuracy= 93.750%
# Iter 20407, Minibatch Loss= 1.929, Minibatch Accuracy= 78.125%
# Iter 20507, Minibatch Loss= 1.825, Minibatch Accuracy= 84.375%
# Iter 20607, Minibatch Loss= 1.787, Minibatch Accuracy= 82.812%
# Iter 20707, Minibatch Loss= 1.805, Minibatch Accuracy= 79.688%
# Iter 20807, Minibatch Loss= 1.819, Minibatch Accuracy= 85.938%
# Iter 20907, Minibatch Loss= 1.825, Minibatch Accuracy= 81.250%
# Iter 21007, Minibatch Loss= 1.705, Minibatch Accuracy= 85.938%
#
# Epoch 27, Validation Loss= 1.421, validation Accuracy= 82.723%
# Epoch 27, Average Training Loss= 1.821, Average Training Accuracy= 82.706%
# Checkpoint created!
#
# Iter 21088, Minibatch Loss= 1.736, Minibatch Accuracy= 89.062%
# Iter 21188, Minibatch Loss= 1.734, Minibatch Accuracy= 84.375%
# Iter 21288, Minibatch Loss= 1.850, Minibatch Accuracy= 73.438%
# Iter 21388, Minibatch Loss= 1.858, Minibatch Accuracy= 79.688%
# Iter 21488, Minibatch Loss= 1.749, Minibatch Accuracy= 89.062%
# Iter 21588, Minibatch Loss= 1.753, Minibatch Accuracy= 82.812%
# Iter 21688, Minibatch Loss= 1.773, Minibatch Accuracy= 82.812%
# Iter 21788, Minibatch Loss= 1.716, Minibatch Accuracy= 89.062%
#
# Epoch 28, Validation Loss= 1.413, validation Accuracy= 83.012%
# Epoch 28, Average Training Loss= 1.798, Average Training Accuracy= 83.145%
# Checkpoint created!
#
# Iter 21869, Minibatch Loss= 1.804, Minibatch Accuracy= 82.812%
# Iter 21969, Minibatch Loss= 1.820, Minibatch Accuracy= 79.688%
# Iter 22069, Minibatch Loss= 1.712, Minibatch Accuracy= 82.812%
# Iter 22169, Minibatch Loss= 1.714, Minibatch Accuracy= 84.375%
# Iter 22269, Minibatch Loss= 1.767, Minibatch Accuracy= 89.062%
# Iter 22369, Minibatch Loss= 1.690, Minibatch Accuracy= 90.625%
# Iter 22469, Minibatch Loss= 1.778, Minibatch Accuracy= 81.250%
# Iter 22569, Minibatch Loss= 1.649, Minibatch Accuracy= 85.938%
#
# Epoch 29, Validation Loss= 1.376, validation Accuracy= 83.221%
# Epoch 29, Average Training Loss= 1.773, Average Training Accuracy= 83.725%
# Checkpoint created!
#
# Iter 22650, Minibatch Loss= 1.762, Minibatch Accuracy= 81.250%
# Iter 22750, Minibatch Loss= 1.747, Minibatch Accuracy= 85.938%
# Iter 22850, Minibatch Loss= 1.721, Minibatch Accuracy= 90.625%
# Iter 22950, Minibatch Loss= 1.813, Minibatch Accuracy= 79.688%
# Iter 23050, Minibatch Loss= 1.820, Minibatch Accuracy= 84.375%
# Iter 23150, Minibatch Loss= 1.720, Minibatch Accuracy= 84.375%
# Iter 23250, Minibatch Loss= 1.782, Minibatch Accuracy= 79.688%
# Iter 23350, Minibatch Loss= 1.740, Minibatch Accuracy= 79.688%
#
# Epoch 30, Validation Loss= 1.352, validation Accuracy= 84.415%
# Epoch 30, Average Training Loss= 1.753, Average Training Accuracy= 83.945%
# Checkpoint created!
#
# Iter 23431, Minibatch Loss= 1.609, Minibatch Accuracy= 90.625%
# Iter 23531, Minibatch Loss= 1.841, Minibatch Accuracy= 81.250%
# Iter 23631, Minibatch Loss= 1.695, Minibatch Accuracy= 90.625%
# Iter 23731, Minibatch Loss= 1.685, Minibatch Accuracy= 84.375%
# Iter 23831, Minibatch Loss= 1.755, Minibatch Accuracy= 90.625%
# Iter 23931, Minibatch Loss= 1.839, Minibatch Accuracy= 76.562%
# Iter 24031, Minibatch Loss= 1.710, Minibatch Accuracy= 90.625%
# Iter 24131, Minibatch Loss= 1.675, Minibatch Accuracy= 89.062%
#
# Epoch 31, Validation Loss= 1.335, validation Accuracy= 84.196%
# Epoch 31, Average Training Loss= 1.730, Average Training Accuracy= 84.609%
#
# Iter 24212, Minibatch Loss= 1.749, Minibatch Accuracy= 84.375%
# Iter 24312, Minibatch Loss= 1.797, Minibatch Accuracy= 76.562%
# Iter 24412, Minibatch Loss= 1.658, Minibatch Accuracy= 89.062%
# Iter 24512, Minibatch Loss= 1.987, Minibatch Accuracy= 68.750%
# Iter 24612, Minibatch Loss= 1.734, Minibatch Accuracy= 82.812%
# Iter 24712, Minibatch Loss= 1.690, Minibatch Accuracy= 89.062%
# Iter 24812, Minibatch Loss= 1.670, Minibatch Accuracy= 87.500%
# Iter 24912, Minibatch Loss= 1.631, Minibatch Accuracy= 92.188%
#
# Epoch 32, Validation Loss= 1.306, validation Accuracy= 84.992%
# Epoch 32, Average Training Loss= 1.707, Average Training Accuracy= 85.187%
# Checkpoint created!
#
# Iter 24993, Minibatch Loss= 1.732, Minibatch Accuracy= 82.812%
# Iter 25093, Minibatch Loss= 1.681, Minibatch Accuracy= 87.500%
# Iter 25193, Minibatch Loss= 1.829, Minibatch Accuracy= 75.000%
# Iter 25293, Minibatch Loss= 1.693, Minibatch Accuracy= 84.375%
# Iter 25393, Minibatch Loss= 1.820, Minibatch Accuracy= 81.250%
# Iter 25493, Minibatch Loss= 1.688, Minibatch Accuracy= 82.812%
# Iter 25593, Minibatch Loss= 1.672, Minibatch Accuracy= 84.375%
# Iter 25693, Minibatch Loss= 1.744, Minibatch Accuracy= 85.938%
#
# Epoch 33, Validation Loss= 1.289, validation Accuracy= 84.962%
# Epoch 33, Average Training Loss= 1.690, Average Training Accuracy= 85.393%
#
# Iter 25774, Minibatch Loss= 1.730, Minibatch Accuracy= 82.812%
# Iter 25874, Minibatch Loss= 1.757, Minibatch Accuracy= 81.250%
# Iter 25974, Minibatch Loss= 1.701, Minibatch Accuracy= 82.812%
# Iter 26074, Minibatch Loss= 1.707, Minibatch Accuracy= 84.375%
# Iter 26174, Minibatch Loss= 1.650, Minibatch Accuracy= 85.938%
# Iter 26274, Minibatch Loss= 1.682, Minibatch Accuracy= 82.812%
# Iter 26374, Minibatch Loss= 1.652, Minibatch Accuracy= 84.375%
# Iter 26474, Minibatch Loss= 1.684, Minibatch Accuracy= 85.938%
#
# Epoch 34, Validation Loss= 1.280, validation Accuracy= 85.151%
# Epoch 34, Average Training Loss= 1.671, Average Training Accuracy= 85.697%
# Checkpoint created!
#
# Iter 26555, Minibatch Loss= 1.601, Minibatch Accuracy= 89.062%
# Iter 26655, Minibatch Loss= 1.682, Minibatch Accuracy= 87.500%
# Iter 26755, Minibatch Loss= 1.611, Minibatch Accuracy= 90.625%
# Iter 26855, Minibatch Loss= 1.687, Minibatch Accuracy= 85.938%
# Iter 26955, Minibatch Loss= 1.627, Minibatch Accuracy= 85.938%
# Iter 27055, Minibatch Loss= 1.510, Minibatch Accuracy= 92.188%
# Iter 27155, Minibatch Loss= 1.781, Minibatch Accuracy= 79.688%
# Iter 27255, Minibatch Loss= 1.663, Minibatch Accuracy= 87.500%
#
# Epoch 35, Validation Loss= 1.260, validation Accuracy= 85.609%
# Epoch 35, Average Training Loss= 1.650, Average Training Accuracy= 86.104%
# Checkpoint created!
#
# Iter 27336, Minibatch Loss= 1.676, Minibatch Accuracy= 85.938%
# Iter 27436, Minibatch Loss= 1.488, Minibatch Accuracy= 93.750%
# Iter 27536, Minibatch Loss= 1.635, Minibatch Accuracy= 90.625%
# Iter 27636, Minibatch Loss= 1.584, Minibatch Accuracy= 87.500%
# Iter 27736, Minibatch Loss= 1.590, Minibatch Accuracy= 89.062%
# Iter 27836, Minibatch Loss= 1.571, Minibatch Accuracy= 90.625%
# Iter 27936, Minibatch Loss= 1.588, Minibatch Accuracy= 89.062%
# Iter 28036, Minibatch Loss= 1.671, Minibatch Accuracy= 85.938%
#
# Epoch 36, Validation Loss= 1.228, validation Accuracy= 85.908%
# Epoch 36, Average Training Loss= 1.632, Average Training Accuracy= 86.476%
# Checkpoint created!
#
# Iter 28117, Minibatch Loss= 1.597, Minibatch Accuracy= 89.062%
# Iter 28217, Minibatch Loss= 1.735, Minibatch Accuracy= 79.688%
# Iter 28317, Minibatch Loss= 1.605, Minibatch Accuracy= 85.938%
# Iter 28417, Minibatch Loss= 1.495, Minibatch Accuracy= 90.625%
# Iter 28517, Minibatch Loss= 1.701, Minibatch Accuracy= 81.250%
# Iter 28617, Minibatch Loss= 1.572, Minibatch Accuracy= 90.625%
# Iter 28717, Minibatch Loss= 1.654, Minibatch Accuracy= 79.688%
# Iter 28817, Minibatch Loss= 1.504, Minibatch Accuracy= 92.188%
#
# Epoch 37, Validation Loss= 1.240, validation Accuracy= 85.111%
# Epoch 37, Average Training Loss= 1.615, Average Training Accuracy= 86.702%
#
# Iter 28898, Minibatch Loss= 1.728, Minibatch Accuracy= 81.250%
# Iter 28998, Minibatch Loss= 1.657, Minibatch Accuracy= 84.375%
# Iter 29098, Minibatch Loss= 1.533, Minibatch Accuracy= 87.500%
# Iter 29198, Minibatch Loss= 1.697, Minibatch Accuracy= 81.250%
# Iter 29298, Minibatch Loss= 1.480, Minibatch Accuracy= 93.750%
# Iter 29398, Minibatch Loss= 1.549, Minibatch Accuracy= 89.062%
# Iter 29498, Minibatch Loss= 1.614, Minibatch Accuracy= 84.375%
# Iter 29598, Minibatch Loss= 1.486, Minibatch Accuracy= 89.062%
#
# Epoch 38, Validation Loss= 1.205, validation Accuracy= 86.276%
# Epoch 38, Average Training Loss= 1.593, Average Training Accuracy= 87.278%
# Checkpoint created!
#
# Iter 29679, Minibatch Loss= 1.535, Minibatch Accuracy= 85.938%
# Iter 29779, Minibatch Loss= 1.554, Minibatch Accuracy= 92.188%
# Iter 29879, Minibatch Loss= 1.489, Minibatch Accuracy= 93.750%
# Iter 29979, Minibatch Loss= 1.640, Minibatch Accuracy= 79.688%
# Iter 30079, Minibatch Loss= 1.634, Minibatch Accuracy= 84.375%
# Iter 30179, Minibatch Loss= 1.526, Minibatch Accuracy= 90.625%
# Iter 30279, Minibatch Loss= 1.580, Minibatch Accuracy= 87.500%
# Iter 30379, Minibatch Loss= 1.742, Minibatch Accuracy= 82.812%
#
# Epoch 39, Validation Loss= 1.187, validation Accuracy= 86.435%
# Epoch 39, Average Training Loss= 1.579, Average Training Accuracy= 87.356%
# Checkpoint created!
#
# Iter 30460, Minibatch Loss= 1.536, Minibatch Accuracy= 89.062%
# Iter 30560, Minibatch Loss= 1.588, Minibatch Accuracy= 85.938%
# Iter 30660, Minibatch Loss= 1.407, Minibatch Accuracy= 96.875%
# Iter 30760, Minibatch Loss= 1.614, Minibatch Accuracy= 85.938%
# Iter 30860, Minibatch Loss= 1.455, Minibatch Accuracy= 95.312%
# Iter 30960, Minibatch Loss= 1.588, Minibatch Accuracy= 89.062%
# Iter 31060, Minibatch Loss= 1.648, Minibatch Accuracy= 89.062%
# Iter 31160, Minibatch Loss= 1.475, Minibatch Accuracy= 90.625%
#
# Epoch 40, Validation Loss= 1.189, validation Accuracy= 86.077%
# Epoch 40, Average Training Loss= 1.559, Average Training Accuracy= 87.866%
#
# Iter 31241, Minibatch Loss= 1.502, Minibatch Accuracy= 85.938%
# Iter 31341, Minibatch Loss= 1.525, Minibatch Accuracy= 89.062%
# Iter 31441, Minibatch Loss= 1.569, Minibatch Accuracy= 85.938%
# Iter 31541, Minibatch Loss= 1.614, Minibatch Accuracy= 78.125%
# Iter 31641, Minibatch Loss= 1.611, Minibatch Accuracy= 82.812%
# Iter 31741, Minibatch Loss= 1.527, Minibatch Accuracy= 85.938%
# Iter 31841, Minibatch Loss= 1.531, Minibatch Accuracy= 89.062%
# Iter 31941, Minibatch Loss= 1.408, Minibatch Accuracy= 95.312%
#
# Epoch 41, Validation Loss= 1.158, validation Accuracy= 86.316%
# Epoch 41, Average Training Loss= 1.542, Average Training Accuracy= 88.142%
#
# Iter 32022, Minibatch Loss= 1.446, Minibatch Accuracy= 93.750%
# Iter 32122, Minibatch Loss= 1.506, Minibatch Accuracy= 87.500%
# Iter 32222, Minibatch Loss= 1.496, Minibatch Accuracy= 90.625%
# Iter 32322, Minibatch Loss= 1.520, Minibatch Accuracy= 89.062%
# Iter 32422, Minibatch Loss= 1.444, Minibatch Accuracy= 93.750%
# Iter 32522, Minibatch Loss= 1.403, Minibatch Accuracy= 95.312%
# Iter 32622, Minibatch Loss= 1.550, Minibatch Accuracy= 87.500%
# Iter 32722, Minibatch Loss= 1.630, Minibatch Accuracy= 82.812%
#
# Epoch 42, Validation Loss= 1.158, validation Accuracy= 86.276%
# Epoch 42, Average Training Loss= 1.530, Average Training Accuracy= 88.186%
#
# Iter 32803, Minibatch Loss= 1.545, Minibatch Accuracy= 89.062%
# Iter 32903, Minibatch Loss= 1.385, Minibatch Accuracy= 96.875%
# Iter 33003, Minibatch Loss= 1.630, Minibatch Accuracy= 84.375%
# Iter 33103, Minibatch Loss= 1.623, Minibatch Accuracy= 85.938%
# Iter 33203, Minibatch Loss= 1.501, Minibatch Accuracy= 85.938%
# Iter 33303, Minibatch Loss= 1.424, Minibatch Accuracy= 93.750%
# Iter 33403, Minibatch Loss= 1.534, Minibatch Accuracy= 87.500%
# Iter 33503, Minibatch Loss= 1.624, Minibatch Accuracy= 82.812%
#
# Epoch 43, Validation Loss= 1.123, validation Accuracy= 87.201%
# Epoch 43, Average Training Loss= 1.513, Average Training Accuracy= 88.594%
# Checkpoint created!
#
# Iter 33584, Minibatch Loss= 1.612, Minibatch Accuracy= 85.938%
# Iter 33684, Minibatch Loss= 1.445, Minibatch Accuracy= 92.188%
# Iter 33784, Minibatch Loss= 1.459, Minibatch Accuracy= 90.625%
# Iter 33884, Minibatch Loss= 1.547, Minibatch Accuracy= 82.812%
# Iter 33984, Minibatch Loss= 1.457, Minibatch Accuracy= 90.625%
# Iter 34084, Minibatch Loss= 1.496, Minibatch Accuracy= 82.812%
# Iter 34184, Minibatch Loss= 1.422, Minibatch Accuracy= 92.188%
# Iter 34284, Minibatch Loss= 1.562, Minibatch Accuracy= 87.500%
#
# Epoch 44, Validation Loss= 1.115, validation Accuracy= 87.520%
# Epoch 44, Average Training Loss= 1.494, Average Training Accuracy= 88.868%
# Checkpoint created!
#
# Iter 34365, Minibatch Loss= 1.397, Minibatch Accuracy= 96.875%
# Iter 34465, Minibatch Loss= 1.431, Minibatch Accuracy= 90.625%
# Iter 34565, Minibatch Loss= 1.455, Minibatch Accuracy= 90.625%
# Iter 34665, Minibatch Loss= 1.579, Minibatch Accuracy= 89.062%
# Iter 34765, Minibatch Loss= 1.499, Minibatch Accuracy= 89.062%
# Iter 34865, Minibatch Loss= 1.355, Minibatch Accuracy= 95.312%
# Iter 34965, Minibatch Loss= 1.424, Minibatch Accuracy= 95.312%
# Iter 35065, Minibatch Loss= 1.530, Minibatch Accuracy= 84.375%
#
# Epoch 45, Validation Loss= 1.106, validation Accuracy= 87.172%
# Epoch 45, Average Training Loss= 1.480, Average Training Accuracy= 89.101%
#
# Iter 35146, Minibatch Loss= 1.534, Minibatch Accuracy= 87.500%
# Iter 35246, Minibatch Loss= 1.442, Minibatch Accuracy= 92.188%
# Iter 35346, Minibatch Loss= 1.522, Minibatch Accuracy= 81.250%
# Iter 35446, Minibatch Loss= 1.400, Minibatch Accuracy= 92.188%
# Iter 35546, Minibatch Loss= 1.403, Minibatch Accuracy= 92.188%
# Iter 35646, Minibatch Loss= 1.488, Minibatch Accuracy= 92.188%
# Iter 35746, Minibatch Loss= 1.450, Minibatch Accuracy= 93.750%
# Iter 35846, Minibatch Loss= 1.415, Minibatch Accuracy= 92.188%
#
# Epoch 46, Validation Loss= 1.094, validation Accuracy= 87.520%
# Epoch 46, Average Training Loss= 1.464, Average Training Accuracy= 89.435%
# Checkpoint created!
#
# Iter 35927, Minibatch Loss= 1.442, Minibatch Accuracy= 87.500%
# Iter 36027, Minibatch Loss= 1.518, Minibatch Accuracy= 90.625%
# Iter 36127, Minibatch Loss= 1.471, Minibatch Accuracy= 85.938%
# Iter 36227, Minibatch Loss= 1.382, Minibatch Accuracy= 90.625%
# Iter 36327, Minibatch Loss= 1.428, Minibatch Accuracy= 93.750%
# Iter 36427, Minibatch Loss= 1.423, Minibatch Accuracy= 89.062%
# Iter 36527, Minibatch Loss= 1.508, Minibatch Accuracy= 89.062%
# Iter 36627, Minibatch Loss= 1.539, Minibatch Accuracy= 87.500%
#
# Epoch 47, Validation Loss= 1.077, validation Accuracy= 87.231%
# Epoch 47, Average Training Loss= 1.452, Average Training Accuracy= 89.611%
#
# Iter 36708, Minibatch Loss= 1.464, Minibatch Accuracy= 92.188%
# Iter 36808, Minibatch Loss= 1.438, Minibatch Accuracy= 90.625%
# Iter 36908, Minibatch Loss= 1.482, Minibatch Accuracy= 87.500%
# Iter 37008, Minibatch Loss= 1.469, Minibatch Accuracy= 90.625%
# Iter 37108, Minibatch Loss= 1.482, Minibatch Accuracy= 87.500%
# Iter 37208, Minibatch Loss= 1.398, Minibatch Accuracy= 92.188%
# Iter 37308, Minibatch Loss= 1.460, Minibatch Accuracy= 89.062%
# Iter 37408, Minibatch Loss= 1.469, Minibatch Accuracy= 87.500%
#
# Epoch 48, Validation Loss= 1.063, validation Accuracy= 87.848%
# Epoch 48, Average Training Loss= 1.438, Average Training Accuracy= 89.777%
# Checkpoint created!
#
# Iter 37489, Minibatch Loss= 1.434, Minibatch Accuracy= 90.625%
# Iter 37589, Minibatch Loss= 1.422, Minibatch Accuracy= 89.062%
# Iter 37689, Minibatch Loss= 1.349, Minibatch Accuracy= 95.312%
# Iter 37789, Minibatch Loss= 1.498, Minibatch Accuracy= 87.500%
# Iter 37889, Minibatch Loss= 1.451, Minibatch Accuracy= 90.625%
# Iter 37989, Minibatch Loss= 1.401, Minibatch Accuracy= 93.750%
# Iter 38089, Minibatch Loss= 1.353, Minibatch Accuracy= 95.312%
# Iter 38189, Minibatch Loss= 1.373, Minibatch Accuracy= 95.312%
#
# Epoch 49, Validation Loss= 1.060, validation Accuracy= 87.430%
# Epoch 49, Average Training Loss= 1.421, Average Training Accuracy= 90.099%
#
# Iter 38270, Minibatch Loss= 1.377, Minibatch Accuracy= 89.062%
# Iter 38370, Minibatch Loss= 1.369, Minibatch Accuracy= 90.625%
# Iter 38470, Minibatch Loss= 1.429, Minibatch Accuracy= 93.750%
# Iter 38570, Minibatch Loss= 1.439, Minibatch Accuracy= 89.062%
# Iter 38670, Minibatch Loss= 1.420, Minibatch Accuracy= 87.500%
# Iter 38770, Minibatch Loss= 1.395, Minibatch Accuracy= 93.750%
# Iter 38870, Minibatch Loss= 1.451, Minibatch Accuracy= 89.062%
# Iter 38970, Minibatch Loss= 1.457, Minibatch Accuracy= 87.500%
#
# Epoch 50, Validation Loss= 1.031, validation Accuracy= 88.167%
# Epoch 50, Average Training Loss= 1.409, Average Training Accuracy= 90.251%
# Checkpoint created!
#
# Iter 39051, Minibatch Loss= 1.435, Minibatch Accuracy= 85.938%
# Iter 39151, Minibatch Loss= 1.509, Minibatch Accuracy= 87.500%
# Iter 39251, Minibatch Loss= 1.470, Minibatch Accuracy= 85.938%
# Iter 39351, Minibatch Loss= 1.561, Minibatch Accuracy= 81.250%
# Iter 39451, Minibatch Loss= 1.340, Minibatch Accuracy= 93.750%
# Iter 39551, Minibatch Loss= 1.429, Minibatch Accuracy= 89.062%
# Iter 39651, Minibatch Loss= 1.385, Minibatch Accuracy= 90.625%
# Iter 39751, Minibatch Loss= 1.443, Minibatch Accuracy= 87.500%
#
# Epoch 51, Validation Loss= 1.016, validation Accuracy= 88.187%
# Epoch 51, Average Training Loss= 1.395, Average Training Accuracy= 90.477%
# Checkpoint created!
#
# Iter 39832, Minibatch Loss= 1.344, Minibatch Accuracy= 89.062%
# Iter 39932, Minibatch Loss= 1.456, Minibatch Accuracy= 87.500%
# Iter 40032, Minibatch Loss= 1.363, Minibatch Accuracy= 92.188%
# Iter 40132, Minibatch Loss= 1.374, Minibatch Accuracy= 92.188%
# Iter 40232, Minibatch Loss= 1.370, Minibatch Accuracy= 90.625%
# Iter 40332, Minibatch Loss= 1.367, Minibatch Accuracy= 90.625%
# Iter 40432, Minibatch Loss= 1.312, Minibatch Accuracy= 96.875%
# Iter 40532, Minibatch Loss= 1.373, Minibatch Accuracy= 90.625%
#
# Epoch 52, Validation Loss= 1.017, validation Accuracy= 88.057%
# Epoch 52, Average Training Loss= 1.379, Average Training Accuracy= 90.849%
#
# Iter 40613, Minibatch Loss= 1.479, Minibatch Accuracy= 85.938%
# Iter 40713, Minibatch Loss= 1.392, Minibatch Accuracy= 89.062%
# Iter 40813, Minibatch Loss= 1.319, Minibatch Accuracy= 92.188%
# Iter 40913, Minibatch Loss= 1.357, Minibatch Accuracy= 95.312%
# Iter 41013, Minibatch Loss= 1.365, Minibatch Accuracy= 90.625%
# Iter 41113, Minibatch Loss= 1.312, Minibatch Accuracy= 90.625%
# Iter 41213, Minibatch Loss= 1.329, Minibatch Accuracy= 92.188%
# Iter 41313, Minibatch Loss= 1.302, Minibatch Accuracy= 95.312%
#
# Epoch 53, Validation Loss= 0.996, validation Accuracy= 88.445%
# Epoch 53, Average Training Loss= 1.368, Average Training Accuracy= 91.037%
# Checkpoint created!
#
# Iter 41394, Minibatch Loss= 1.361, Minibatch Accuracy= 90.625%
# Iter 41494, Minibatch Loss= 1.448, Minibatch Accuracy= 90.625%
# Iter 41594, Minibatch Loss= 1.289, Minibatch Accuracy= 93.750%
# Iter 41694, Minibatch Loss= 1.332, Minibatch Accuracy= 95.312%
# Iter 41794, Minibatch Loss= 1.313, Minibatch Accuracy= 93.750%
# Iter 41894, Minibatch Loss= 1.356, Minibatch Accuracy= 89.062%
# Iter 41994, Minibatch Loss= 1.325, Minibatch Accuracy= 92.188%
# Iter 42094, Minibatch Loss= 1.414, Minibatch Accuracy= 90.625%
#
# Epoch 54, Validation Loss= 1.018, validation Accuracy= 87.639%
# Epoch 54, Average Training Loss= 1.356, Average Training Accuracy= 91.229%
#
# Iter 42175, Minibatch Loss= 1.341, Minibatch Accuracy= 89.062%
# Iter 42275, Minibatch Loss= 1.353, Minibatch Accuracy= 89.062%
# Iter 42375, Minibatch Loss= 1.360, Minibatch Accuracy= 89.062%
# Iter 42475, Minibatch Loss= 1.367, Minibatch Accuracy= 93.750%
# Iter 42575, Minibatch Loss= 1.356, Minibatch Accuracy= 89.062%
# Iter 42675, Minibatch Loss= 1.309, Minibatch Accuracy= 95.312%
# Iter 42775, Minibatch Loss= 1.270, Minibatch Accuracy= 93.750%
# Iter 42875, Minibatch Loss= 1.360, Minibatch Accuracy= 87.500%
#
# Epoch 55, Validation Loss= 0.983, validation Accuracy= 88.635%
# Epoch 55, Average Training Loss= 1.341, Average Training Accuracy= 91.493%
# Checkpoint created!
#
# Iter 42956, Minibatch Loss= 1.253, Minibatch Accuracy= 96.875%
# Iter 43056, Minibatch Loss= 1.339, Minibatch Accuracy= 93.750%
# Iter 43156, Minibatch Loss= 1.464, Minibatch Accuracy= 84.375%
# Iter 43256, Minibatch Loss= 1.349, Minibatch Accuracy= 92.188%
# Iter 43356, Minibatch Loss= 1.321, Minibatch Accuracy= 89.062%
# Iter 43456, Minibatch Loss= 1.265, Minibatch Accuracy= 93.750%
# Iter 43556, Minibatch Loss= 1.306, Minibatch Accuracy= 92.188%
# Iter 43656, Minibatch Loss= 1.444, Minibatch Accuracy= 84.375%
#
# Epoch 56, Validation Loss= 0.979, validation Accuracy= 87.948%
# Epoch 56, Average Training Loss= 1.328, Average Training Accuracy= 91.739%
#
# Iter 43737, Minibatch Loss= 1.331, Minibatch Accuracy= 95.312%
# Iter 43837, Minibatch Loss= 1.269, Minibatch Accuracy= 92.188%
# Iter 43937, Minibatch Loss= 1.260, Minibatch Accuracy= 95.312%
# Iter 44037, Minibatch Loss= 1.276, Minibatch Accuracy= 89.062%
# Iter 44137, Minibatch Loss= 1.304, Minibatch Accuracy= 90.625%
# Iter 44237, Minibatch Loss= 1.275, Minibatch Accuracy= 93.750%
# Iter 44337, Minibatch Loss= 1.296, Minibatch Accuracy= 90.625%
# Iter 44437, Minibatch Loss= 1.293, Minibatch Accuracy= 93.750%
#
# Epoch 57, Validation Loss= 0.983, validation Accuracy= 88.077%
# Epoch 57, Average Training Loss= 1.317, Average Training Accuracy= 91.961%
#
# Iter 44518, Minibatch Loss= 1.353, Minibatch Accuracy= 90.625%
# Iter 44618, Minibatch Loss= 1.286, Minibatch Accuracy= 92.188%
# Iter 44718, Minibatch Loss= 1.249, Minibatch Accuracy= 95.312%
# Iter 44818, Minibatch Loss= 1.418, Minibatch Accuracy= 87.500%
# Iter 44918, Minibatch Loss= 1.279, Minibatch Accuracy= 92.188%
# Iter 45018, Minibatch Loss= 1.314, Minibatch Accuracy= 89.062%
# Iter 45118, Minibatch Loss= 1.222, Minibatch Accuracy= 96.875%
# Iter 45218, Minibatch Loss= 1.357, Minibatch Accuracy= 87.500%
#
# Epoch 58, Validation Loss= 0.955, validation Accuracy= 88.674%
# Epoch 58, Average Training Loss= 1.306, Average Training Accuracy= 92.003%
# Checkpoint created!
#
# Iter 45299, Minibatch Loss= 1.285, Minibatch Accuracy= 90.625%
# Iter 45399, Minibatch Loss= 1.324, Minibatch Accuracy= 89.062%
# Iter 45499, Minibatch Loss= 1.259, Minibatch Accuracy= 93.750%
# Iter 45599, Minibatch Loss= 1.243, Minibatch Accuracy= 93.750%
# Iter 45699, Minibatch Loss= 1.315, Minibatch Accuracy= 89.062%
# Iter 45799, Minibatch Loss= 1.326, Minibatch Accuracy= 87.500%
# Iter 45899, Minibatch Loss= 1.288, Minibatch Accuracy= 92.188%
# Iter 45999, Minibatch Loss= 1.268, Minibatch Accuracy= 93.750%
#
# Epoch 59, Validation Loss= 0.933, validation Accuracy= 89.142%
# Epoch 59, Average Training Loss= 1.294, Average Training Accuracy= 92.097%
# Checkpoint created!
#
# Iter 46080, Minibatch Loss= 1.267, Minibatch Accuracy= 92.188%
# Iter 46180, Minibatch Loss= 1.247, Minibatch Accuracy= 90.625%
# Iter 46280, Minibatch Loss= 1.257, Minibatch Accuracy= 93.750%
# Iter 46380, Minibatch Loss= 1.212, Minibatch Accuracy= 95.312%
# Iter 46480, Minibatch Loss= 1.200, Minibatch Accuracy= 95.312%
# Iter 46580, Minibatch Loss= 1.379, Minibatch Accuracy= 87.500%
# Iter 46680, Minibatch Loss= 1.315, Minibatch Accuracy= 87.500%
# Iter 46780, Minibatch Loss= 1.306, Minibatch Accuracy= 92.188%
#
# Epoch 60, Validation Loss= 0.932, validation Accuracy= 88.684%
# Epoch 60, Average Training Loss= 1.282, Average Training Accuracy= 92.274%
#
# Iter 46861, Minibatch Loss= 1.215, Minibatch Accuracy= 92.188%
# Iter 46961, Minibatch Loss= 1.358, Minibatch Accuracy= 87.500%
# Iter 47061, Minibatch Loss= 1.249, Minibatch Accuracy= 92.188%
# Iter 47161, Minibatch Loss= 1.264, Minibatch Accuracy= 90.625%
# Iter 47261, Minibatch Loss= 1.283, Minibatch Accuracy= 90.625%
# Iter 47361, Minibatch Loss= 1.214, Minibatch Accuracy= 95.312%
# Iter 47461, Minibatch Loss= 1.196, Minibatch Accuracy= 96.875%
# Iter 47561, Minibatch Loss= 1.250, Minibatch Accuracy= 92.188%
#
# Epoch 61, Validation Loss= 0.920, validation Accuracy= 88.854%
# Epoch 61, Average Training Loss= 1.270, Average Training Accuracy= 92.428%
#
# Iter 47642, Minibatch Loss= 1.292, Minibatch Accuracy= 92.188%
# Iter 47742, Minibatch Loss= 1.174, Minibatch Accuracy= 96.875%
# Iter 47842, Minibatch Loss= 1.244, Minibatch Accuracy= 93.750%
# Iter 47942, Minibatch Loss= 1.310, Minibatch Accuracy= 89.062%
# Iter 48042, Minibatch Loss= 1.239, Minibatch Accuracy= 92.188%
# Iter 48142, Minibatch Loss= 1.253, Minibatch Accuracy= 93.750%
# Iter 48242, Minibatch Loss= 1.329, Minibatch Accuracy= 89.062%
# Iter 48342, Minibatch Loss= 1.223, Minibatch Accuracy= 93.750%
#
# Epoch 62, Validation Loss= 0.924, validation Accuracy= 89.062%
# Epoch 62, Average Training Loss= 1.256, Average Training Accuracy= 92.772%
#
# Iter 48423, Minibatch Loss= 1.276, Minibatch Accuracy= 90.625%
# Iter 48523, Minibatch Loss= 1.182, Minibatch Accuracy= 98.438%
# Iter 48623, Minibatch Loss= 1.287, Minibatch Accuracy= 90.625%
# Iter 48723, Minibatch Loss= 1.204, Minibatch Accuracy= 96.875%
# Iter 48823, Minibatch Loss= 1.239, Minibatch Accuracy= 93.750%
# Iter 48923, Minibatch Loss= 1.254, Minibatch Accuracy= 92.188%
# Iter 49023, Minibatch Loss= 1.247, Minibatch Accuracy= 93.750%
# Iter 49123, Minibatch Loss= 1.283, Minibatch Accuracy= 90.625%
#
# Epoch 63, Validation Loss= 0.908, validation Accuracy= 89.013%
# Epoch 63, Average Training Loss= 1.246, Average Training Accuracy= 92.826%
#
# Iter 49204, Minibatch Loss= 1.248, Minibatch Accuracy= 95.312%
# Iter 49304, Minibatch Loss= 1.207, Minibatch Accuracy= 90.625%
# Iter 49404, Minibatch Loss= 1.273, Minibatch Accuracy= 90.625%
# Iter 49504, Minibatch Loss= 1.157, Minibatch Accuracy= 98.438%
# Iter 49604, Minibatch Loss= 1.134, Minibatch Accuracy= 100.000%
# Iter 49704, Minibatch Loss= 1.261, Minibatch Accuracy= 89.062%
# Iter 49804, Minibatch Loss= 1.350, Minibatch Accuracy= 89.062%
# Iter 49904, Minibatch Loss= 1.235, Minibatch Accuracy= 95.312%
#
# Epoch 64, Validation Loss= 0.897, validation Accuracy= 88.794%
# Epoch 64, Average Training Loss= 1.236, Average Training Accuracy= 93.128%
#
# Iter 49985, Minibatch Loss= 1.174, Minibatch Accuracy= 96.875%
# Iter 50085, Minibatch Loss= 1.219, Minibatch Accuracy= 92.188%
# Iter 50185, Minibatch Loss= 1.164, Minibatch Accuracy= 96.875%
# Iter 50285, Minibatch Loss= 1.278, Minibatch Accuracy= 89.062%
# Iter 50385, Minibatch Loss= 1.251, Minibatch Accuracy= 93.750%
# Iter 50485, Minibatch Loss= 1.197, Minibatch Accuracy= 93.750%
# Iter 50585, Minibatch Loss= 1.217, Minibatch Accuracy= 90.625%
# Iter 50685, Minibatch Loss= 1.277, Minibatch Accuracy= 89.062%
#
# Epoch 65, Validation Loss= 0.877, validation Accuracy= 89.580%
# Epoch 65, Average Training Loss= 1.228, Average Training Accuracy= 93.068%
# Checkpoint created!
#
# Iter 50766, Minibatch Loss= 1.187, Minibatch Accuracy= 96.875%
# Iter 50866, Minibatch Loss= 1.240, Minibatch Accuracy= 92.188%
# Iter 50966, Minibatch Loss= 1.210, Minibatch Accuracy= 93.750%
# Iter 51066, Minibatch Loss= 1.268, Minibatch Accuracy= 89.062%
# Iter 51166, Minibatch Loss= 1.161, Minibatch Accuracy= 95.312%
# Iter 51266, Minibatch Loss= 1.253, Minibatch Accuracy= 92.188%
# Iter 51366, Minibatch Loss= 1.217, Minibatch Accuracy= 93.750%
# Iter 51466, Minibatch Loss= 1.186, Minibatch Accuracy= 96.875%
#
# Epoch 66, Validation Loss= 0.872, validation Accuracy= 89.500%
# Epoch 66, Average Training Loss= 1.213, Average Training Accuracy= 93.520%
#
# Iter 51547, Minibatch Loss= 1.295, Minibatch Accuracy= 89.062%
# Iter 51647, Minibatch Loss= 1.348, Minibatch Accuracy= 85.938%
# Iter 51747, Minibatch Loss= 1.239, Minibatch Accuracy= 90.625%
# Iter 51847, Minibatch Loss= 1.207, Minibatch Accuracy= 95.312%
# Iter 51947, Minibatch Loss= 1.194, Minibatch Accuracy= 90.625%
# Iter 52047, Minibatch Loss= 1.272, Minibatch Accuracy= 89.062%
# Iter 52147, Minibatch Loss= 1.213, Minibatch Accuracy= 89.062%
# Iter 52247, Minibatch Loss= 1.222, Minibatch Accuracy= 87.500%
#
# Epoch 67, Validation Loss= 0.883, validation Accuracy= 88.953%
# Epoch 67, Average Training Loss= 1.206, Average Training Accuracy= 93.398%
#
# Iter 52328, Minibatch Loss= 1.150, Minibatch Accuracy= 95.312%
# Iter 52428, Minibatch Loss= 1.187, Minibatch Accuracy= 93.750%
# Iter 52528, Minibatch Loss= 1.220, Minibatch Accuracy= 90.625%
# Iter 52628, Minibatch Loss= 1.172, Minibatch Accuracy= 96.875%
# Iter 52728, Minibatch Loss= 1.242, Minibatch Accuracy= 92.188%
# Iter 52828, Minibatch Loss= 1.253, Minibatch Accuracy= 87.500%
# Iter 52928, Minibatch Loss= 1.139, Minibatch Accuracy= 96.875%
# Iter 53028, Minibatch Loss= 1.248, Minibatch Accuracy= 89.062%
#
# Epoch 68, Validation Loss= 0.857, validation Accuracy= 89.670%
# Epoch 68, Average Training Loss= 1.195, Average Training Accuracy= 93.624%
# Checkpoint created!
#
# Iter 53109, Minibatch Loss= 1.137, Minibatch Accuracy= 96.875%
# Iter 53209, Minibatch Loss= 1.254, Minibatch Accuracy= 92.188%
# Iter 53309, Minibatch Loss= 1.212, Minibatch Accuracy= 93.750%
# Iter 53409, Minibatch Loss= 1.173, Minibatch Accuracy= 93.750%
# Iter 53509, Minibatch Loss= 1.171, Minibatch Accuracy= 95.312%
# Iter 53609, Minibatch Loss= 1.220, Minibatch Accuracy= 85.938%
# Iter 53709, Minibatch Loss= 1.145, Minibatch Accuracy= 96.875%
# Iter 53809, Minibatch Loss= 1.146, Minibatch Accuracy= 96.875%
#
# Epoch 69, Validation Loss= 0.856, validation Accuracy= 89.590%
# Epoch 69, Average Training Loss= 1.186, Average Training Accuracy= 93.748%
#
# Iter 53890, Minibatch Loss= 1.157, Minibatch Accuracy= 95.312%
# Iter 53990, Minibatch Loss= 1.237, Minibatch Accuracy= 90.625%
# Iter 54090, Minibatch Loss= 1.184, Minibatch Accuracy= 92.188%
# Iter 54190, Minibatch Loss= 1.210, Minibatch Accuracy= 92.188%
# Iter 54290, Minibatch Loss= 1.188, Minibatch Accuracy= 95.312%
# Iter 54390, Minibatch Loss= 1.178, Minibatch Accuracy= 93.750%
# Iter 54490, Minibatch Loss= 1.210, Minibatch Accuracy= 90.625%
# Iter 54590, Minibatch Loss= 1.197, Minibatch Accuracy= 95.312%
#
# Epoch 70, Validation Loss= 0.844, validation Accuracy= 89.620%
# Epoch 70, Average Training Loss= 1.176, Average Training Accuracy= 93.920%
#
# Iter 54671, Minibatch Loss= 1.129, Minibatch Accuracy= 98.438%
# Iter 54771, Minibatch Loss= 1.203, Minibatch Accuracy= 93.750%
# Iter 54871, Minibatch Loss= 1.201, Minibatch Accuracy= 95.312%
# Iter 54971, Minibatch Loss= 1.191, Minibatch Accuracy= 92.188%
# Iter 55071, Minibatch Loss= 1.143, Minibatch Accuracy= 96.875%
# Iter 55171, Minibatch Loss= 1.176, Minibatch Accuracy= 92.188%
# Iter 55271, Minibatch Loss= 1.183, Minibatch Accuracy= 92.188%
# Iter 55371, Minibatch Loss= 1.097, Minibatch Accuracy= 96.875%
#
# Epoch 71, Validation Loss= 0.844, validation Accuracy= 89.371%
# Epoch 71, Average Training Loss= 1.168, Average Training Accuracy= 93.948%
#
# Iter 55452, Minibatch Loss= 1.216, Minibatch Accuracy= 92.188%
# Iter 55552, Minibatch Loss= 1.129, Minibatch Accuracy= 95.312%
# Iter 55652, Minibatch Loss= 1.191, Minibatch Accuracy= 92.188%
# Iter 55752, Minibatch Loss= 1.157, Minibatch Accuracy= 92.188%
# Iter 55852, Minibatch Loss= 1.154, Minibatch Accuracy= 92.188%
# Iter 55952, Minibatch Loss= 1.149, Minibatch Accuracy= 95.312%
# Iter 56052, Minibatch Loss= 1.161, Minibatch Accuracy= 96.875%
# Iter 56152, Minibatch Loss= 1.140, Minibatch Accuracy= 93.750%
#
# Epoch 72, Validation Loss= 0.830, validation Accuracy= 89.371%
# Epoch 72, Average Training Loss= 1.158, Average Training Accuracy= 94.112%
#
# Iter 56233, Minibatch Loss= 1.168, Minibatch Accuracy= 93.750%
# Iter 56333, Minibatch Loss= 1.115, Minibatch Accuracy= 93.750%
# Iter 56433, Minibatch Loss= 1.147, Minibatch Accuracy= 93.750%
# Iter 56533, Minibatch Loss= 1.122, Minibatch Accuracy= 95.312%
# Iter 56633, Minibatch Loss= 1.221, Minibatch Accuracy= 87.500%
# Iter 56733, Minibatch Loss= 1.086, Minibatch Accuracy= 98.438%
# Iter 56833, Minibatch Loss= 1.110, Minibatch Accuracy= 95.312%
# Iter 56933, Minibatch Loss= 1.160, Minibatch Accuracy= 95.312%
#
# Epoch 73, Validation Loss= 0.819, validation Accuracy= 89.938%
# Epoch 73, Average Training Loss= 1.148, Average Training Accuracy= 94.246%
# Checkpoint created!
#
# Iter 57014, Minibatch Loss= 1.148, Minibatch Accuracy= 95.312%
# Iter 57114, Minibatch Loss= 1.104, Minibatch Accuracy= 98.438%
# ...
#
# Iter 149172, Minibatch Loss= 0.662, Minibatch Accuracy= 100.000%
# Iter 149272, Minibatch Loss= 0.701, Minibatch Accuracy= 96.875%
# Iter 149372, Minibatch Loss= 0.656, Minibatch Accuracy= 100.000%
# Iter 149472, Minibatch Loss= 0.660, Minibatch Accuracy= 100.000%
# Iter 149572, Minibatch Loss= 0.675, Minibatch Accuracy= 98.438%
# Iter 149672, Minibatch Loss= 0.693, Minibatch Accuracy= 98.438%
# Iter 149772, Minibatch Loss= 0.692, Minibatch Accuracy= 98.438%
# Iter 149872, Minibatch Loss= 0.670, Minibatch Accuracy= 98.438%
#
# Epoch 192, Validation Loss= 0.474, validation Accuracy= 91.381%
# Epoch 192, Average Training Loss= 0.682, Average Training Accuracy= 98.584%
#
# Iter 149953, Minibatch Loss= 0.685, Minibatch Accuracy= 98.438%
# Iter 150053, Minibatch Loss= 0.694, Minibatch Accuracy= 96.875%
# Iter 150153, Minibatch Loss= 0.655, Minibatch Accuracy= 100.000%
# Iter 150253, Minibatch Loss= 0.671, Minibatch Accuracy= 100.000%
# Iter 150353, Minibatch Loss= 0.664, Minibatch Accuracy= 100.000%
# Iter 150453, Minibatch Loss= 0.669, Minibatch Accuracy= 98.438%
# Iter 150553, Minibatch Loss= 0.691, Minibatch Accuracy= 96.875%
# Iter 150653, Minibatch Loss= 0.700, Minibatch Accuracy= 96.875%
#
# Epoch 193, Validation Loss= 0.443, validation Accuracy= 91.829%
# Epoch 193, Average Training Loss= 0.676, Average Training Accuracy= 98.790%
#
# Iter 150734, Minibatch Loss= 0.658, Minibatch Accuracy= 100.000%
# Iter 150834, Minibatch Loss= 0.683, Minibatch Accuracy= 96.875%
# Iter 150934, Minibatch Loss= 0.668, Minibatch Accuracy= 100.000%
# Iter 151034, Minibatch Loss= 0.666, Minibatch Accuracy= 100.000%
# Iter 151134, Minibatch Loss= 0.651, Minibatch Accuracy= 100.000%
# Iter 151234, Minibatch Loss= 0.676, Minibatch Accuracy= 98.438%
# Iter 151334, Minibatch Loss= 0.676, Minibatch Accuracy= 100.000%
# Iter 151434, Minibatch Loss= 0.717, Minibatch Accuracy= 95.312%
#
# Epoch 194, Validation Loss= 0.449, validation Accuracy= 92.088%
# Epoch 194, Average Training Loss= 0.679, Average Training Accuracy= 98.638%
#
# Iter 151515, Minibatch Loss= 0.702, Minibatch Accuracy= 96.875%
# Iter 151615, Minibatch Loss= 0.687, Minibatch Accuracy= 98.438%
# Iter 151715, Minibatch Loss= 0.710, Minibatch Accuracy= 95.312%
# Iter 151815, Minibatch Loss= 0.657, Minibatch Accuracy= 100.000%
# Iter 151915, Minibatch Loss= 0.649, Minibatch Accuracy= 100.000%
# Iter 152015, Minibatch Loss= 0.681, Minibatch Accuracy= 98.438%
# Iter 152115, Minibatch Loss= 0.694, Minibatch Accuracy= 98.438%
# Iter 152215, Minibatch Loss= 0.690, Minibatch Accuracy= 96.875%
#
# Epoch 195, Validation Loss= 0.440, validation Accuracy= 92.247%
# Epoch 195, Average Training Loss= 0.677, Average Training Accuracy= 98.640%
#
# Iter 152296, Minibatch Loss= 0.695, Minibatch Accuracy= 96.875%
# Iter 152396, Minibatch Loss= 0.668, Minibatch Accuracy= 100.000%
# Iter 152496, Minibatch Loss= 0.652, Minibatch Accuracy= 100.000%
# Iter 152596, Minibatch Loss= 0.709, Minibatch Accuracy= 95.312%
# Iter 152696, Minibatch Loss= 0.661, Minibatch Accuracy= 100.000%
# Iter 152796, Minibatch Loss= 0.647, Minibatch Accuracy= 100.000%
# Iter 152896, Minibatch Loss= 0.666, Minibatch Accuracy= 100.000%
# Iter 152996, Minibatch Loss= 0.663, Minibatch Accuracy= 100.000%
#
# Epoch 196, Validation Loss= 0.451, validation Accuracy= 91.929%
# Epoch 196, Average Training Loss= 0.678, Average Training Accuracy= 98.598%
#
# Iter 153077, Minibatch Loss= 0.686, Minibatch Accuracy= 96.875%
# Iter 153177, Minibatch Loss= 0.741, Minibatch Accuracy= 93.750%
# Iter 153277, Minibatch Loss= 0.653, Minibatch Accuracy= 100.000%
# Iter 153377, Minibatch Loss= 0.655, Minibatch Accuracy= 100.000%
# Iter 153477, Minibatch Loss= 0.652, Minibatch Accuracy= 100.000%
# Iter 153577, Minibatch Loss= 0.685, Minibatch Accuracy= 98.438%
# Iter 153677, Minibatch Loss= 0.678, Minibatch Accuracy= 96.875%
# Iter 153777, Minibatch Loss= 0.681, Minibatch Accuracy= 96.875%
#
# Epoch 197, Validation Loss= 0.437, validation Accuracy= 92.188%
# Epoch 197, Average Training Loss= 0.676, Average Training Accuracy= 98.596%
#
# Iter 153858, Minibatch Loss= 0.685, Minibatch Accuracy= 96.875%
# Iter 153958, Minibatch Loss= 0.654, Minibatch Accuracy= 100.000%
# Iter 154058, Minibatch Loss= 0.680, Minibatch Accuracy= 98.438%
# Iter 154158, Minibatch Loss= 0.684, Minibatch Accuracy= 98.438%
# Iter 154258, Minibatch Loss= 0.647, Minibatch Accuracy= 100.000%
# Iter 154358, Minibatch Loss= 0.645, Minibatch Accuracy= 100.000%
# Iter 154458, Minibatch Loss= 0.682, Minibatch Accuracy= 98.438%
# Iter 154558, Minibatch Loss= 0.672, Minibatch Accuracy= 96.875%
#
# Epoch 198, Validation Loss= 0.443, validation Accuracy= 92.078%
# Epoch 198, Average Training Loss= 0.672, Average Training Accuracy= 98.684%
#
# Iter 154639, Minibatch Loss= 0.648, Minibatch Accuracy= 100.000%
# Iter 154739, Minibatch Loss= 0.674, Minibatch Accuracy= 100.000%
# Iter 154839, Minibatch Loss= 0.676, Minibatch Accuracy= 100.000%
# Iter 154939, Minibatch Loss= 0.692, Minibatch Accuracy= 96.875%
# Iter 155039, Minibatch Loss= 0.675, Minibatch Accuracy= 96.875%
# Iter 155139, Minibatch Loss= 0.688, Minibatch Accuracy= 98.438%
# Iter 155239, Minibatch Loss= 0.644, Minibatch Accuracy= 100.000%
# Iter 155339, Minibatch Loss= 0.688, Minibatch Accuracy= 96.875%
#
# Epoch 199, Validation Loss= 0.437, validation Accuracy= 92.426%
# Epoch 199, Average Training Loss= 0.670, Average Training Accuracy= 98.778%
#
# Iter 155420, Minibatch Loss= 0.646, Minibatch Accuracy= 100.000%
# Iter 155520, Minibatch Loss= 0.653, Minibatch Accuracy= 100.000%
# Iter 155620, Minibatch Loss= 0.664, Minibatch Accuracy= 100.000%
# Iter 155720, Minibatch Loss= 0.662, Minibatch Accuracy= 100.000%
# Iter 155820, Minibatch Loss= 0.695, Minibatch Accuracy= 96.875%
# Iter 155920, Minibatch Loss= 0.733, Minibatch Accuracy= 93.750%
# Iter 156020, Minibatch Loss= 0.666, Minibatch Accuracy= 98.438%
# Iter 156120, Minibatch Loss= 0.659, Minibatch Accuracy= 100.000%
#
# Epoch 200, Validation Loss= 0.442, validation Accuracy= 92.217%
# Epoch 200, Average Training Loss= 0.671, Average Training Accuracy= 98.692%
#
# Iter 156201, Minibatch Loss= 0.648, Minibatch Accuracy= 100.000%
# Iter 156301, Minibatch Loss= 0.647, Minibatch Accuracy= 100.000%
# Iter 156401, Minibatch Loss= 0.658, Minibatch Accuracy= 98.438%
# Iter 156501, Minibatch Loss= 0.675, Minibatch Accuracy= 100.000%
# Iter 156601, Minibatch Loss= 0.670, Minibatch Accuracy= 98.438%
# Iter 156701, Minibatch Loss= 0.691, Minibatch Accuracy= 100.000%
# Iter 156801, Minibatch Loss= 0.706, Minibatch Accuracy= 96.875%
# Iter 156901, Minibatch Loss= 0.666, Minibatch Accuracy= 100.000%
#
# Epoch 201, Validation Loss= 0.435, validation Accuracy= 92.168%
# Epoch 201, Average Training Loss= 0.669, Average Training Accuracy= 98.776%
# Iter 156982, Minibatch Loss= 0.674, Minibatch Accuracy= 98.438%
# Iter 157082, Minibatch Loss= 0.660, Minibatch Accuracy= 100.000%
# Iter 157182, Minibatch Loss= 0.677, Minibatch Accuracy= 98.438%
# Iter 157282, Minibatch Loss= 0.660, Minibatch Accuracy= 98.438%
# Iter 157382, Minibatch Loss= 0.665, Minibatch Accuracy= 98.438%
# Iter 157482, Minibatch Loss= 0.656, Minibatch Accuracy= 98.438%
# Iter 157582, Minibatch Loss= 0.663, Minibatch Accuracy= 98.438%
# Iter 157682, Minibatch Loss= 0.650, Minibatch Accuracy= 100.000%
#
# Epoch 202, Validation Loss= 0.453, validation Accuracy= 91.879%
# Epoch 202, Average Training Loss= 0.670, Average Training Accuracy= 98.656%
#
# Iter 157763, Minibatch Loss= 0.664, Minibatch Accuracy= 98.438%
# Iter 157863, Minibatch Loss= 0.655, Minibatch Accuracy= 100.000%
# Iter 157963, Minibatch Loss= 0.673, Minibatch Accuracy= 98.438%
# Iter 158063, Minibatch Loss= 0.682, Minibatch Accuracy= 98.438%
# Iter 158163, Minibatch Loss= 0.718, Minibatch Accuracy= 95.312%
# Iter 158263, Minibatch Loss= 0.649, Minibatch Accuracy= 100.000%
# Iter 158363, Minibatch Loss= 0.651, Minibatch Accuracy= 100.000%
# Iter 158463, Minibatch Loss= 0.650, Minibatch Accuracy= 100.000%
#
# Epoch 203, Validation Loss= 0.440, validation Accuracy= 91.889%
# Epoch 203, Average Training Loss= 0.670, Average Training Accuracy= 98.644%
#
# Iter 158544, Minibatch Loss= 0.656, Minibatch Accuracy= 98.438%
# Iter 158644, Minibatch Loss= 0.670, Minibatch Accuracy= 96.875%
# Iter 158744, Minibatch Loss= 0.687, Minibatch Accuracy= 96.875%
# Iter 158844, Minibatch Loss= 0.651, Minibatch Accuracy= 100.000%
# Iter 158944, Minibatch Loss= 0.686, Minibatch Accuracy= 98.438%
# Iter 159044, Minibatch Loss= 0.684, Minibatch Accuracy= 96.875%
# Iter 159144, Minibatch Loss= 0.641, Minibatch Accuracy= 100.000%
# Iter 159244, Minibatch Loss= 0.663, Minibatch Accuracy= 98.438%
#
# Epoch 204, Validation Loss= 0.436, validation Accuracy= 92.078%
# Epoch 204, Average Training Loss= 0.666, Average Training Accuracy= 98.686%
#
# Iter 159325, Minibatch Loss= 0.635, Minibatch Accuracy= 100.000%
# Iter 159425, Minibatch Loss= 0.671, Minibatch Accuracy= 96.875%
# Iter 159525, Minibatch Loss= 0.662, Minibatch Accuracy= 100.000%
# Iter 159625, Minibatch Loss= 0.649, Minibatch Accuracy= 98.438%
# Iter 159725, Minibatch Loss= 0.669, Minibatch Accuracy= 98.438%
# Iter 159825, Minibatch Loss= 0.662, Minibatch Accuracy= 98.438%
# Iter 159925, Minibatch Loss= 0.654, Minibatch Accuracy= 100.000%
# Iter 160025, Minibatch Loss= 0.649, Minibatch Accuracy= 100.000%
#
# Epoch 205, Validation Loss= 0.432, validation Accuracy= 92.148%
# Epoch 205, Average Training Loss= 0.666, Average Training Accuracy= 98.708%
#
# Iter 160106, Minibatch Loss= 0.669, Minibatch Accuracy= 98.438%
# Iter 160206, Minibatch Loss= 0.661, Minibatch Accuracy= 100.000%
# Iter 160306, Minibatch Loss= 0.659, Minibatch Accuracy= 98.438%
# Iter 160406, Minibatch Loss= 0.656, Minibatch Accuracy= 100.000%
# Iter 160506, Minibatch Loss= 0.660, Minibatch Accuracy= 98.438%
# Iter 160606, Minibatch Loss= 0.705, Minibatch Accuracy= 95.312%
# Iter 160706, Minibatch Loss= 0.707, Minibatch Accuracy= 98.438%
# Iter 160806, Minibatch Loss= 0.682, Minibatch Accuracy= 96.875%
#
# Epoch 206, Validation Loss= 0.447, validation Accuracy= 91.640%
# Epoch 206, Average Training Loss= 0.667, Average Training Accuracy= 98.614%
#
# Iter 160887, Minibatch Loss= 0.651, Minibatch Accuracy= 100.000%
# Iter 160987, Minibatch Loss= 0.652, Minibatch Accuracy= 100.000%
# Iter 161087, Minibatch Loss= 0.702, Minibatch Accuracy= 96.875%
# Iter 161187, Minibatch Loss= 0.653, Minibatch Accuracy= 100.000%
# Iter 161287, Minibatch Loss= 0.696, Minibatch Accuracy= 95.312%
# Iter 161387, Minibatch Loss= 0.651, Minibatch Accuracy= 100.000%
# Iter 161487, Minibatch Loss= 0.660, Minibatch Accuracy= 100.000%
# Iter 161587, Minibatch Loss= 0.675, Minibatch Accuracy= 98.438%
#
# Epoch 207, Validation Loss= 0.439, validation Accuracy= 92.158%
# Epoch 207, Average Training Loss= 0.663, Average Training Accuracy= 98.768%
#
# Iter 161668, Minibatch Loss= 0.651, Minibatch Accuracy= 100.000%
# Iter 161768, Minibatch Loss= 0.651, Minibatch Accuracy= 100.000%
# Iter 161868, Minibatch Loss= 0.663, Minibatch Accuracy= 98.438%
# Iter 161968, Minibatch Loss= 0.650, Minibatch Accuracy= 100.000%
# Iter 162068, Minibatch Loss= 0.662, Minibatch Accuracy= 98.438%
# Iter 162168, Minibatch Loss= 0.684, Minibatch Accuracy= 100.000%
# Iter 162268, Minibatch Loss= 0.635, Minibatch Accuracy= 100.000%
# Iter 162368, Minibatch Loss= 0.648, Minibatch Accuracy= 98.438%
#
# Epoch 208, Validation Loss= 0.430, validation Accuracy= 92.148%
# Epoch 208, Average Training Loss= 0.662, Average Training Accuracy= 98.744%
#
# Iter 162449, Minibatch Loss= 0.643, Minibatch Accuracy= 100.000%
# Iter 162549, Minibatch Loss= 0.673, Minibatch Accuracy= 98.438%
# Iter 162649, Minibatch Loss= 0.688, Minibatch Accuracy= 95.312%
# Iter 162749, Minibatch Loss= 0.648, Minibatch Accuracy= 100.000%
# Iter 162849, Minibatch Loss= 0.702, Minibatch Accuracy= 93.750%
# Iter 162949, Minibatch Loss= 0.692, Minibatch Accuracy= 95.312%
# Iter 163049, Minibatch Loss= 0.696, Minibatch Accuracy= 98.438%
# Iter 163149, Minibatch Loss= 0.701, Minibatch Accuracy= 96.875%
#
# Epoch 209, Validation Loss= 0.436, validation Accuracy= 91.929%
# Epoch 209, Average Training Loss= 0.666, Average Training Accuracy= 98.498%
#
# Iter 163230, Minibatch Loss= 0.631, Minibatch Accuracy= 100.000%
# Iter 163330, Minibatch Loss= 0.686, Minibatch Accuracy= 98.438%
# Iter 163430, Minibatch Loss= 0.745, Minibatch Accuracy= 96.875%
# Iter 163530, Minibatch Loss= 0.671, Minibatch Accuracy= 98.438%
# Iter 163630, Minibatch Loss= 0.646, Minibatch Accuracy= 100.000%
# Iter 163730, Minibatch Loss= 0.670, Minibatch Accuracy= 96.875%
# Iter 163830, Minibatch Loss= 0.654, Minibatch Accuracy= 98.438%
# Iter 163930, Minibatch Loss= 0.638, Minibatch Accuracy= 100.000%
#
# Epoch 210, Validation Loss= 0.429, validation Accuracy= 92.108%
# Epoch 210, Average Training Loss= 0.660, Average Training Accuracy= 98.756%
#
# Iter 164011, Minibatch Loss= 0.673, Minibatch Accuracy= 98.438%
# Iter 164111, Minibatch Loss= 0.646, Minibatch Accuracy= 100.000%
# Iter 164211, Minibatch Loss= 0.634, Minibatch Accuracy= 100.000%
# Iter 164311, Minibatch Loss= 0.667, Minibatch Accuracy= 98.438%
# Iter 164411, Minibatch Loss= 0.641, Minibatch Accuracy= 100.000%
# Iter 164511, Minibatch Loss= 0.641, Minibatch Accuracy= 100.000%
# Iter 164611, Minibatch Loss= 0.642, Minibatch Accuracy= 100.000%
# Iter 164711, Minibatch Loss= 0.654, Minibatch Accuracy= 100.000%
#
# Epoch 211, Validation Loss= 0.437, validation Accuracy= 92.078%
# Epoch 211, Average Training Loss= 0.662, Average Training Accuracy= 98.626%
#
# Iter 164792, Minibatch Loss= 0.679, Minibatch Accuracy= 98.438%
# Iter 164892, Minibatch Loss= 0.634, Minibatch Accuracy= 100.000%
# Iter 164992, Minibatch Loss= 0.644, Minibatch Accuracy= 100.000%
# Iter 165092, Minibatch Loss= 0.676, Minibatch Accuracy= 98.438%
# Iter 165192, Minibatch Loss= 0.676, Minibatch Accuracy= 98.438%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b858aba39833> in <module>()
#      38                                    feed_dict={x: batches_X[i], y: batches_Y[i],
#      39                                    keep_prob: 0.7,
# ---> 40                                    phase: True})
#      41             total_loss += loss
#      42             total_acc += acc
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Saving logs about change of training and validation loss and accuracy over epochs in another file.

import h5py

file = h5py.File('Training_logs.h5','w')
file.create_dataset('val_acc', data=np.array(val_acc_list))
file.create_dataset('val_loss', data=np.array(val_loss_list))
file.create_dataset('acc', data=np.array(acc_list))
file.create_dataset('loss', data=np.array(loss_list))

file.close()

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

log = h5py.File('Training_logs.h5','r+') # Loading logs about change of training and validation loss and accuracy over epochs

y1 = log['val_acc'][...]
y2 = log['acc'][...]

x = np.arange(1,len(y1)+1,1) # (1 = starting epoch, len(y1) = no. of epochs, 1 = step) 

plt.plot(x,y1,'b',label='Validation Accuracy') 
plt.plot(x,y2,'r',label='Training Accuracy')
plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.show()

y1 = log['val_loss'][...]
y2 = log['loss'][...]

plt.plot(x,y1,'b',label='Validation Loss')
plt.plot(x,y2,'r',label='Training Loss')
plt.legend(loc='upper right')
plt.xlabel('epoch')
plt.show()
